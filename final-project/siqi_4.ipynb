# %% [markdown]
# ## 1. Load packages

# %%
# data processing packages
import numpy as np
from numpy import random
import pandas as pd
import re

# machine learning packages
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn import metrics
from sklearn.decomposition import PCA

# visualization packages
import seaborn as sb
import matplotlib.pyplot as plt

# other packages
import torch
from pathlib import Path
import random
import itertools
import time

# %% [markdown]
# ## 2. Read the files

# %%
## Create the necessary folders
Path('./Figures/').mkdir(parents=True, exist_ok=True)
Path('./Results/').mkdir(parents=True, exist_ok=True)

# %%
## Set path to the data set
dataset_path = "./dataset/77_cancer_proteomes_CPTAC_itraq.csv"
clinical_info = "./dataset/clinical_data_breast_cancer.csv"
pam50_proteins = "./dataset/PAM50_proteins.csv"

## Load data
data = pd.read_csv(dataset_path,header=0,index_col=0)
clinical_file = pd.read_csv(clinical_info,header=0,index_col=0) ## holds clinical information about each patient/sample
pam50 = pd.read_csv(pam50_proteins,header=0)

# RefSeq protein ID (each protein has a unique ID in a RefSeq database)
print(data.index.name)
data.head()
# Out:
# RefSeq_accession_number
#                         gene_symbol           gene_name  AO-A12D.01TCGA  \
# RefSeq_accession_number
# NP_958782                      PLEC   plectin isoform 1        1.096131
# NP_958785                       NaN  plectin isoform 1g        1.111370
# NP_958786                      PLEC  plectin isoform 1a        1.111370
# NP_000436                       NaN  plectin isoform 1c        1.107561
# NP_958781                       NaN  plectin isoform 1e        1.115180
#
#                          C8-A131.01TCGA  AO-A12B.01TCGA  BH-A18Q.02TCGA  \
# RefSeq_accession_number
# NP_958782                      2.609943       -0.659828        0.195341
# NP_958785                      2.650422       -0.648742        0.215413
# NP_958786                      2.650422       -0.654285        0.215413
# NP_000436                      2.646374       -0.632113        0.205377
# NP_958781                      2.646374       -0.640428        0.215413
#
#                          C8-A130.02TCGA  C8-A138.03TCGA  E2-A154.03TCGA  \
# RefSeq_accession_number
# NP_958782                     -0.494060        2.765081        0.862659
# NP_958785                     -0.503899        2.779709        0.870186
# NP_958786                     -0.500619        2.779709        0.870186
# NP_000436                     -0.510459        2.797995        0.866423
# NP_958781                     -0.503899        2.787023        0.870186
#
#                          C8-A12L.04TCGA  ...  AO-A12B.34TCGA  A2-A0SW.35TCGA  \
# RefSeq_accession_number                  ...
# NP_958782                      1.407570  ...       -0.963904       -0.487772
# NP_958785                      1.407570  ...       -0.938210       -0.487772
# NP_958786                      1.410312  ...       -0.943919       -0.487772
# NP_000436                      1.407570  ...       -0.935355       -0.487772
# NP_958781                      1.413053  ...       -0.935355       -0.503853
#
#                          AO-A0JL.35TCGA  BH-A0BV.35TCGA  A2-A0YM.36TCGA  \
# RefSeq_accession_number
# NP_958782                      -0.10668       -0.065838        0.655850
# NP_958785                      -0.10668       -0.055893        0.658143
# NP_958786                      -0.10668       -0.065838        0.655850
# NP_000436                      -0.10668       -0.055893        0.655850
# NP_958781                      -0.10668       -0.062523        0.651264
#
#                          BH-A0C7.36TCGA  A2-A0SX.36TCGA  263d3f-I.CPTAC  \
# RefSeq_accession_number
# NP_958782                     -0.552212       -0.398560        0.598585
# NP_958785                     -0.547749       -0.392601        0.606697
# NP_958786                     -0.552212       -0.392601        0.603993
# NP_000436                     -0.552212       -0.392601        0.603993
# NP_958781                     -0.556675       -0.395581        0.603993
#
#                          blcdb9-I.CPTAC  c4155b-C.CPTAC
# RefSeq_accession_number
# NP_958782                     -0.191285        0.566975
# NP_958785                     -0.183918        0.578702
# NP_958786                     -0.186022        0.576747
# NP_000436                     -0.186022        0.576747
# NP_958781                     -0.167079        0.576747
#
# [5 rows x 85 columns]

# %% [markdown]
# ## 3. Data Set Processing

# %%
## Drop unused information columns
data.drop(['gene_symbol','gene_name'],axis=1,inplace=True)

## Change the protein data sample names to a format matching the clinical data set
data.rename(columns=lambda x: "TCGA-%s" % (re.split('[_|-|.]',x)[0]) if bool(re.search("TCGA",x)) is True else x,inplace=True)

data.head()
# Out:
#                          TCGA-AO-A12D  TCGA-C8-A131  TCGA-AO-A12B  \
# RefSeq_accession_number
# NP_958782                    1.096131      2.609943     -0.659828
# NP_958785                    1.111370      2.650422     -0.648742
# NP_958786                    1.111370      2.650422     -0.654285
# NP_000436                    1.107561      2.646374     -0.632113
# NP_958781                    1.115180      2.646374     -0.640428
#
#                          TCGA-BH-A18Q  TCGA-C8-A130  TCGA-C8-A138  \
# RefSeq_accession_number
# NP_958782                    0.195341     -0.494060      2.765081
# NP_958785                    0.215413     -0.503899      2.779709
# NP_958786                    0.215413     -0.500619      2.779709
# NP_000436                    0.205377     -0.510459      2.797995
# NP_958781                    0.215413     -0.503899      2.787023
#
#                          TCGA-E2-A154  TCGA-C8-A12L  TCGA-A2-A0EX  \
# RefSeq_accession_number
# NP_958782                    0.862659      1.407570      1.185108
# NP_958785                    0.870186      1.407570      1.192612
# NP_958786                    0.870186      1.410312      1.188860
# NP_000436                    0.866423      1.407570      1.185108
# NP_958781                    0.870186      1.413053      1.200116
#
#                          TCGA-AO-A12D  ...  TCGA-AO-A12B  TCGA-A2-A0SW  \
# RefSeq_accession_number                ...
# NP_958782                    1.100688  ...     -0.963904     -0.487772
# NP_958785                    1.100688  ...     -0.938210     -0.487772
# NP_958786                    1.100688  ...     -0.943919     -0.487772
# NP_000436                    1.100688  ...     -0.935355     -0.487772
# NP_958781                    1.093358  ...     -0.935355     -0.503853
#
#                          TCGA-AO-A0JL  TCGA-BH-A0BV  TCGA-A2-A0YM  \
# RefSeq_accession_number
# NP_958782                    -0.10668     -0.065838      0.655850
# NP_958785                    -0.10668     -0.055893      0.658143
# NP_958786                    -0.10668     -0.065838      0.655850
# NP_000436                    -0.10668     -0.055893      0.655850
# NP_958781                    -0.10668     -0.062523      0.651264
#
#                          TCGA-BH-A0C7  TCGA-A2-A0SX  263d3f-I.CPTAC  \
# RefSeq_accession_number
# NP_958782                   -0.552212     -0.398560        0.598585
# NP_958785                   -0.547749     -0.392601        0.606697
# NP_958786                   -0.552212     -0.392601        0.603993
# NP_000436                   -0.552212     -0.392601        0.603993
# NP_958781                   -0.556675     -0.395581        0.603993
#
#                          blcdb9-I.CPTAC  c4155b-C.CPTAC
# RefSeq_accession_number
# NP_958782                     -0.191285        0.566975
# NP_958785                     -0.183918        0.578702
# NP_958786                     -0.186022        0.576747
# NP_000436                     -0.186022        0.576747
# NP_958781                     -0.167079        0.576747
#
# [5 rows x 83 columns]

# %%
## Transpose data for the clustering algorithm since we want to divide patient samples, not proteins
print(data.shape)
datat = data.transpose()
print(datat.shape)

datat.head()
# Out:
# (12553, 83)
# (83, 12553)
# RefSeq_accession_number  NP_958782  NP_958785  NP_958786  NP_000436  \
# TCGA-AO-A12D              1.096131   1.111370   1.111370   1.107561
# TCGA-C8-A131              2.609943   2.650422   2.650422   2.646374
# TCGA-AO-A12B             -0.659828  -0.648742  -0.654285  -0.632113
# TCGA-BH-A18Q              0.195341   0.215413   0.215413   0.205377
# TCGA-C8-A130             -0.494060  -0.503899  -0.500619  -0.510459
#
# RefSeq_accession_number  NP_958781  NP_958780  NP_958783  NP_958784  \
# TCGA-AO-A12D              1.115180   1.107561   1.111370   1.111370
# TCGA-C8-A131              2.646374   2.646374   2.650422   2.650422
# TCGA-AO-A12B             -0.640428  -0.654285  -0.648742  -0.648742
# TCGA-BH-A18Q              0.215413   0.215413   0.215413   0.215413
# TCGA-C8-A130             -0.503899  -0.503899  -0.500619  -0.500619
#
# RefSeq_accession_number  NP_112598  NP_001611  ...  NP_001193600  NP_061134  \
# TCGA-AO-A12D             -1.517390   0.482754  ...           NaN        NaN
# TCGA-C8-A131              3.909313  -1.045294  ...           NaN        NaN
# TCGA-AO-A12B             -0.618256   1.222003  ...           NaN        NaN
# TCGA-BH-A18Q             -1.035760  -0.517226  ...      0.048144        NaN
# TCGA-C8-A130             -1.845366  -0.405503  ...      1.457462        NaN
#
# RefSeq_accession_number  NP_932347  NP_003593  NP_997203  NP_001191293  \
# TCGA-AO-A12D                   NaN  -0.340163        NaN           NaN
# TCGA-C8-A131                   NaN   3.451902        NaN           NaN
# TCGA-AO-A12B                   NaN  -1.718531        NaN           NaN
# TCGA-BH-A18Q             -0.881872   2.527072  -8.111243    -16.029761
# TCGA-C8-A130              1.710012   0.296389  -1.753529      1.729692
#
# RefSeq_accession_number  NP_775791  NP_004065  NP_068752  NP_219494
# TCGA-AO-A12D                   NaN        NaN  -0.633517  12.666488
# TCGA-C8-A131                   NaN        NaN   4.840325   0.140736
# TCGA-AO-A12B                   NaN        NaN  -1.965192  -2.854835
# TCGA-BH-A18Q             -2.046065  -1.778435        NaN  -3.069752
# TCGA-C8-A130             -0.425182  -0.149673        NaN  -0.047997
#
# [5 rows x 12553 columns]

# %%
print("Number of patients in clinical data set: ", len(clinical_file.index))
print("Number of patients in protein data set: ", len(datat.index))
# Out:
# Number of patients in clinical data set:  105
# Number of patients in protein data set:  83

# %%
## Drop clinical entries for samples not in our protein data set
clinical = clinical_file.loc[[x for x in clinical_file.index.tolist() if x in datat.index],:]

print("The shape of the clinical data set: ", clinical.shape)
clinical.head()
# Out:
# The shape of the clinical data set:  (77, 29)
#                   Gender  Age at Initial Pathologic Diagnosis ER Status  \
# Complete TCGA ID
# TCGA-A2-A0CM      FEMALE                                   40  Negative
# TCGA-BH-A18Q      FEMALE                                   56  Negative
# TCGA-A7-A0CE      FEMALE                                   57  Negative
# TCGA-D8-A142      FEMALE                                   74  Negative
# TCGA-AO-A0J6      FEMALE                                   61  Negative
#
#                  PR Status HER2 Final Status Tumor Tumor--T1 Coded Node  \
# Complete TCGA ID
# TCGA-A2-A0CM      Negative          Negative    T2         T_Other   N0
# TCGA-BH-A18Q      Negative          Negative    T2         T_Other   N1
# TCGA-A7-A0CE      Negative          Negative    T2         T_Other   N0
# TCGA-D8-A142      Negative          Negative    T3         T_Other   N0
# TCGA-AO-A0J6      Negative          Negative    T2         T_Other   N0
#
#                  Node-Coded Metastasis  ...  PAM50 mRNA  \
# Complete TCGA ID                        ...
# TCGA-A2-A0CM       Negative         M0  ...  Basal-like
# TCGA-BH-A18Q       Positive         M0  ...  Basal-like
# TCGA-A7-A0CE       Negative         M0  ...  Basal-like
# TCGA-D8-A142       Negative         M0  ...  Basal-like
# TCGA-AO-A0J6       Negative         M0  ...  Basal-like
#
#                  SigClust Unsupervised mRNA SigClust Intrinsic mRNA  \
# Complete TCGA ID
# TCGA-A2-A0CM                            -12                     -13
# TCGA-BH-A18Q                            -12                     -13
# TCGA-A7-A0CE                              0                     -13
# TCGA-D8-A142                              0                     -13
# TCGA-AO-A0J6                            -12                     -13
#
#                  miRNA Clusters methylation Clusters  RPPA Clusters  \
# Complete TCGA ID
# TCGA-A2-A0CM                  4                    4          Basal
# TCGA-BH-A18Q                  5                    5          Basal
# TCGA-A7-A0CE                  5                    5          Basal
# TCGA-D8-A142                  3                    5              X
# TCGA-AO-A0J6                  2                    5          Basal
#
#                   CN Clusters  Integrated Clusters (with PAM50)  \
# Complete TCGA ID
# TCGA-A2-A0CM                4                                 2
# TCGA-BH-A18Q                1                                 2
# TCGA-A7-A0CE                1                                 2
# TCGA-D8-A142                1                                 2
# TCGA-AO-A0J6                1                                 2
#
#                   Integrated Clusters (no exp) Integrated Clusters (unsup exp)
# Complete TCGA ID
# TCGA-A2-A0CM                                 1                               1
# TCGA-BH-A18Q                                 2                               2
# TCGA-A7-A0CE                                 2                               2
# TCGA-D8-A142                                 2                               2
# TCGA-AO-A0J6                                 2                               2
#
# [5 rows x 29 columns]

# %%
## Add clinical meta data to our protein data set, note: all numerical features for analysis start with NP_ or XP_
merged = datat.merge(clinical,left_index=True,right_index=True)

# Drop the duplicated columns (added by Pietro Gavazzi)
liste = merged.index.copy()
liste = list(liste)

for i in np.unique(merged.index):
    liste.remove(i)

## Change name to make it look nicer in the code!
processed = merged.drop(np.unique(liste))

print("Shape of the merged data set: ", processed.shape)
print("with %d patients and %d features" % (processed.shape[0], processed.shape[1]))

processed.head()
# Out:
# Shape of the merged data set:  (74, 12582)
# with 74 patients and 12582 features
#               NP_958782  NP_958785  NP_958786  NP_000436  NP_958781  \
# TCGA-A2-A0CM   0.683404   0.694424   0.698098   0.687077   0.687077
# TCGA-A2-A0D2   0.107491   0.104164   0.107491   0.097512   0.104164
# TCGA-A2-A0EQ  -0.912670  -0.927979  -0.927979  -0.931806  -0.927979
# TCGA-A2-A0EV   0.452986   0.472590   0.472590   0.458587   0.472590
# TCGA-A2-A0EX   1.185108   1.192612   1.188860   1.185108   1.200116
#
#               NP_958780  NP_958783  NP_958784  NP_112598  NP_001611  ...  \
# TCGA-A2-A0CM   0.698098   0.698098   0.698098  -2.652150  -0.984373  ...
# TCGA-A2-A0D2   0.104164   0.104164   0.104164  -0.880454  -1.512473  ...
# TCGA-A2-A0EQ  -0.927979  -0.927979  -0.927979  -3.071151  -2.278943  ...
# TCGA-A2-A0EV   0.472590   0.472590   0.472590  -0.742871   1.811277  ...
# TCGA-A2-A0EX   1.188860   1.188860   1.192612   1.046289   2.138081  ...
#
#                  PAM50 mRNA  SigClust Unsupervised mRNA  \
# TCGA-A2-A0CM     Basal-like                         -12
# TCGA-A2-A0D2     Basal-like                         -12
# TCGA-A2-A0EQ  HER2-enriched                          -5
# TCGA-A2-A0EV      Luminal A                          -4
# TCGA-A2-A0EX      Luminal A                          -7
#
#               SigClust Intrinsic mRNA  miRNA Clusters  methylation Clusters  \
# TCGA-A2-A0CM                      -13               4                     4
# TCGA-A2-A0D2                      -13               4                     5
# TCGA-A2-A0EQ                       -2               5                     4
# TCGA-A2-A0EV                        0               4                     2
# TCGA-A2-A0EX                       -5               4                     4
#
#               RPPA Clusters  CN Clusters  Integrated Clusters (with PAM50)  \
# TCGA-A2-A0CM          Basal            4                                 2
# TCGA-A2-A0D2          Basal            3                                 2
# TCGA-A2-A0EQ          Basal            4                                 4
# TCGA-A2-A0EV          ReacI            3                                 3
# TCGA-A2-A0EX          ReacI            4                                 3
#
#               Integrated Clusters (no exp)  Integrated Clusters (unsup exp)
# TCGA-A2-A0CM                             1                                1
# TCGA-A2-A0D2                             2                                2
# TCGA-A2-A0EQ                             1                                1
# TCGA-A2-A0EV                             3                                4
# TCGA-A2-A0EX                             1                                4
#
# [5 rows x 12582 columns]

# %%
## Numerical data for the algorithm, NP_xx/XP_xx are protein identifiers from RefSeq database
X = processed.loc[:,[x for x in processed.columns if bool(re.search("NP_|XP_|YP_",x)) == True]]
Y = pd.get_dummies(processed.drop(X.columns, axis=1)['Integrated Clusters (with PAM50)'], prefix="PAM50")

## Select only the PAM50 proteins - known panel of genes used for breast cancer subtype prediction
# processed_numerical_p50 = processed_numerical.iloc[:,processed_numerical.columns.isin(pam50['RefSeqProteinID'])]
# processed_numerical_p50.head()

X.columns
# Out:
# Index(['NP_958782', 'NP_958785', 'NP_958786', 'NP_000436', 'NP_958781',
#        'NP_958780', 'NP_958783', 'NP_958784', 'NP_112598', 'NP_001611',
#        ...
#        'NP_001193600', 'NP_061134', 'NP_932347', 'NP_003593', 'NP_997203',
#        'NP_001191293', 'NP_775791', 'NP_004065', 'NP_068752', 'NP_219494'],
#       dtype='object', length=12553)

# %%
Y.head()
# Out:
#               PAM50_1  PAM50_2  PAM50_3  PAM50_4
# TCGA-A2-A0CM        0        1        0        0
# TCGA-A2-A0D2        0        1        0        0
# TCGA-A2-A0EQ        0        0        0        1
# TCGA-A2-A0EV        0        0        1        0
# TCGA-A2-A0EX        0        0        1        0

# %%
# Save the data
torch.save(X, './Results/X')
torch.save(Y, './Results/Y')

# %% [markdown]
# ## 3. Data Engineering

# %%
# Read the processed data set
X = torch.load('./Results/X')
Y = torch.load('./Results/Y')

# %%
X.head()
# Out:
#               NP_958782  NP_958785  NP_958786  NP_000436  NP_958781  \
# TCGA-A2-A0CM   0.683404   0.694424   0.698098   0.687077   0.687077
# TCGA-A2-A0D2   0.107491   0.104164   0.107491   0.097512   0.104164
# TCGA-A2-A0EQ  -0.912670  -0.927979  -0.927979  -0.931806  -0.927979
# TCGA-A2-A0EV   0.452986   0.472590   0.472590   0.458587   0.472590
# TCGA-A2-A0EX   1.185108   1.192612   1.188860   1.185108   1.200116
#
#               NP_958780  NP_958783  NP_958784  NP_112598  NP_001611  ...  \
# TCGA-A2-A0CM   0.698098   0.698098   0.698098  -2.652150  -0.984373  ...
# TCGA-A2-A0D2   0.104164   0.104164   0.104164  -0.880454  -1.512473  ...
# TCGA-A2-A0EQ  -0.927979  -0.927979  -0.927979  -3.071151  -2.278943  ...
# TCGA-A2-A0EV   0.472590   0.472590   0.472590  -0.742871   1.811277  ...
# TCGA-A2-A0EX   1.188860   1.188860   1.192612   1.046289   2.138081  ...
#
#               NP_001193600  NP_061134  NP_932347  NP_003593  NP_997203  \
# TCGA-A2-A0CM           NaN        NaN   1.153614        NaN        NaN
# TCGA-A2-A0D2      0.919136  -1.648856   0.832649        NaN  -8.324969
# TCGA-A2-A0EQ     -0.801685        NaN        NaN   3.802310  -6.373934
# TCGA-A2-A0EV     -4.966177  -1.471027        NaN  -0.474013 -12.278546
# TCGA-A2-A0EX      1.451490  -2.018981   0.877456        NaN        NaN
#
#               NP_001191293  NP_775791  NP_004065  NP_068752  NP_219494
# TCGA-A2-A0CM           NaN        NaN        NaN        NaN        NaN
# TCGA-A2-A0D2     -4.679219        NaN  -1.106650        NaN  -6.941181
# TCGA-A2-A0EQ     -1.123160        NaN        NaN        NaN        NaN
# TCGA-A2-A0EV    -10.337729  -0.653251        NaN        NaN        NaN
# TCGA-A2-A0EX     -6.101005        NaN  -1.726336        NaN        NaN
#
# [5 rows x 12553 columns]

# %%
Y.head()
# Out:
#               PAM50_1  PAM50_2  PAM50_3  PAM50_4
# TCGA-A2-A0CM        0        1        0        0
# TCGA-A2-A0D2        0        1        0        0
# TCGA-A2-A0EQ        0        0        0        1
# TCGA-A2-A0EV        0        0        1        0
# TCGA-A2-A0EX        0        0        1        0

# %% [markdown]
# ### 3.1 Missing value process
# We drop all the columns with nan values

# %%
nan_counts = np.sum(X.isna(), axis=0)
col_to_drop = nan_counts[nan_counts != 0].index
X.drop(col_to_drop, axis=1, inplace=True)

# %%
X.shape
# Out:
# (74, 8023)

# %% [markdown]
# ### 3.2 Data Scaling
# We use the standardization for each feature of the data set

# %%
col_names = X.columns
idx = X.index
scaler = StandardScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=col_names, index=idx)
X_scaled.shape
# Out:
# (74, 8023)

# %% [markdown]
# ## 4. Basic model

# %% [markdown]
# ### 4.1 K-Means model

# %%
kmeans = KMeans(n_clusters=4, algorithm='full').fit(X_scaled)
pred0 = kmeans.labels_

# %% [markdown]
# ### 4.2 Evaluation Metric

# %%
# https://medium.com/data-science-in-your-pocket/calculating-precision-recall-for-multi-class-classification-9055931ee229 


permutation_matrices = []
for i in itertools.permutations([0, 1, 2, 3]):
    matrix = np.zeros((4, 4))
    for j in range(len(matrix)):
        matrix[j][i[j]] = 1

    permutation_matrices.append(matrix)



def get_dataframe(y_array_pred, y_true):
    pred = pd.DataFrame(pd.get_dummies(y_array_pred))
    pred.columns = ['cluster_' + str(x) for x in range(1, 5)]
    pred = pred.set_index(y_true.index)
    return(pred)



def calculate_mean_prec(matrix):
    matrix = np.array(matrix)
    assert(matrix.shape[0]==matrix.shape[1]), f"matrix must be squared, same number of true labels {matrix.shape[0]} as predicted{matrix.shape[1]}"

    prec = np.zeros(len(matrix))

    for i in range(len(matrix)):
        true_pos_classified_pos = matrix[i][i]
        classified_pos= np.sum(matrix[i])
        prec[i] = true_pos_classified_pos/classified_pos
    
    return np.mean(prec)

def calculate_mean_recall(matrix):
    matrix = np.array(matrix)
    assert(matrix.shape[0]==matrix.shape[1]), f"matrix must be squared, same number of true labels {matrix.shape[0]} as predicted{matrix.shape[1]}"

    rec = np.zeros(len(matrix.T))

    for i in range(len(matrix.T)):
        true_pos_classified_pos = matrix.T[i][i]
        true_pos= np.sum(matrix.T[i])
        rec[i] = true_pos_classified_pos/true_pos

    return np.mean(rec)


def model_eval(y_true, y_pred):

    length = len(y_true.T)
    assert (y_pred.shape==y_true.shape), f"expected same shape of colums for both y_true: {y_true.shape} and y_pred {y_pred.shape}"
    
    matrix = np.zeros((length, length))

    indi = 0
    for i in y_pred.T.index:
        indj = 0
        for j in y_true.T.index:
            matrix[indi][indj] += np.array(y_pred[i]) @ np.array(y_true[j])
            indj+=1
        indi+=1

    
    matrix = pd.DataFrame(matrix, columns=y_true.T.index, index=y_pred.T.index)


    best_perm = None
    best_Fscore = 0
    best_prec = 0
    best_rec = 0

    ## version 3.0
    for permu_mat in permutation_matrices:
        M = permu_mat@matrix

        prec = calculate_mean_prec(M)
        rec = calculate_mean_recall(M)

        Fscore = 2/(1/prec + 1/rec)
        
        if Fscore > best_Fscore:
            best_perm = permu_mat
            best_Fscore = Fscore
            best_prec = prec
            best_rec = rec
    
    new_matrix = best_perm@matrix

    indexes = []
    for i in range(len(best_perm)):
        for j in range(len(best_perm)):
            if best_perm[i][j]==1:
                indexes.append(matrix.index[j])


    new_matrix.index = indexes

    return new_matrix, best_Fscore, best_prec, best_rec

# %%
y_pred = get_dataframe(pred0, Y)
new_matrix, best_Fscore, best_prec, best_rec = model_eval(Y, y_pred)
new_matrix
# Out:
#            PAM50_1  PAM50_2  PAM50_3  PAM50_4
# cluster_3      4.0      0.0      4.0      6.0
# cluster_2      2.0     12.0      1.0      2.0
# cluster_4      2.0      4.0     10.0      3.0
# cluster_1      2.0      2.0      8.0     12.0

# %%
best_Fscore
# Out:
# 0.5051367432148657

# %% [markdown]
# ## 5. Model improvement

# %%
def feature_selection(X_scaled, Y, min_features, max_features):
    random.seed(42)

    mean_prec_list, std_prec_list = [], []
    mean_rec_list, std_rec_list = [], []
    mean_Fscore_list, std_Fscore_list = [], []

    for num_feature in range(min_features, max_features+1):
        prec_list, rec_list, Fscore_list = [], [], []
        for i in range(50):
            tic = time.time()
            feature_selected = random.choices(X_scaled.columns, k=num_feature)
            if num_feature == 1:
                X_reduced = np.array(X_scaled[feature_selected]).reshape(-1, 1)
            else:
                X_reduced = np.array(X_scaled[feature_selected])
            k_means = KMeans(n_clusters=4).fit(X_reduced)
            pred = k_means.labels_
            y_pred = get_dataframe(pred, Y)
            _, Fscore, prec, rec = model_eval(Y, y_pred)

            prec_list.append(prec)
            rec_list.append(rec)
            Fscore_list.append(Fscore)
            tac = time.time()

            print("[# features: %d] [random attemps: %d] [prec: %.4f] [rec: %.4f] [F-score: %.4f] [T: %.2f]" % (
                num_feature, i, prec, rec, Fscore, (tac-tic)
            ))

        mean_prec_list.append(np.mean(prec_list))
        std_prec_list.append(np.std(prec_list))

        mean_rec_list.append(np.mean(rec_list))
        std_rec_list.append(np.std(rec_list))

        mean_Fscore_list.append(np.mean(Fscore_list))
        std_Fscore_list.append(np.std(Fscore_list))

    return [mean_prec_list, std_prec_list, mean_rec_list, std_rec_list, mean_Fscore_list, std_Fscore_list]

# %%
for i in range(78, 79):
    results_i = feature_selection(X_scaled, Y, (i-1)*100+1, i*100)
    torch.save(results_i, './Results/results_' + str((i-1)*100+1) + '_' + str(i*100))
# Out:
# [# features: 7701] [random attemps: 0] [prec: 0.5426] [rec: 0.5192] [F-score: 0.5307] [T: 0.79]
# [# features: 7701] [random attemps: 1] [prec: 0.5660] [rec: 0.5634] [F-score: 0.5647] [T: 1.13]
# [# features: 7701] [random attemps: 2] [prec: 0.5145] [rec: 0.5229] [F-score: 0.5187] [T: 0.80]
# [# features: 7701] [random attemps: 3] [prec: 0.4933] [rec: 0.5091] [F-score: 0.5010] [T: 0.42]
# [# features: 7701] [random attemps: 4] [prec: 0.4926] [rec: 0.4595] [F-score: 0.4755] [T: 0.58]
# [# features: 7701] [random attemps: 5] [prec: 0.4831] [rec: 0.4674] [F-score: 0.4751] [T: 0.66]
# [# features: 7701] [random attemps: 6] [prec: 0.4391] [rec: 0.4626] [F-score: 0.4505] [T: 0.94]
# [# features: 7701] [random attemps: 7] [prec: 0.4226] [rec: 0.4348] [F-score: 0.4286] [T: 0.89]
# [# features: 7701] [random attemps: 8] [prec: 0.5662] [rec: 0.5463] [F-score: 0.5561] [T: 0.53]
# [# features: 7701] [random attemps: 9] [prec: 0.4244] [rec: 0.4237] [F-score: 0.4240] [T: 0.46]
# [# features: 7701] [random attemps: 10] [prec: 0.5238] [rec: 0.5338] [F-score: 0.5288] [T: 0.33]
# [# features: 7701] [random attemps: 11] [prec: 0.5524] [rec: 0.5664] [F-score: 0.5593] [T: 0.56]
# [# features: 7701] [random attemps: 12] [prec: 0.4590] [rec: 0.4734] [F-score: 0.4661] [T: 0.54]
# [# features: 7701] [random attemps: 13] [prec: 0.4386] [rec: 0.4376] [F-score: 0.4381] [T: 0.60]
# [# features: 7701] [random attemps: 14] [prec: 0.5375] [rec: 0.5444] [F-score: 0.5409] [T: 0.35]
# [# features: 7701] [random attemps: 15] [prec: 0.5185] [rec: 0.5308] [F-score: 0.5246] [T: 0.49]
# [# features: 7701] [random attemps: 16] [prec: 0.5764] [rec: 0.5713] [F-score: 0.5738] [T: 0.77]
# [# features: 7701] [random attemps: 17] [prec: 0.4497] [rec: 0.4752] [F-score: 0.4621] [T: 0.54]
# [# features: 7701] [random attemps: 18] [prec: 0.4607] [rec: 0.4419] [F-score: 0.4511] [T: 0.44]
# [# features: 7701] [random attemps: 19] [prec: 0.5376] [rec: 0.5275] [F-score: 0.5325] [T: 0.34]
# [# features: 7701] [random attemps: 20] [prec: 0.5124] [rec: 0.5030] [F-score: 0.5077] [T: 0.32]
# [# features: 7701] [random attemps: 21] [prec: 0.4861] [rec: 0.4752] [F-score: 0.4806] [T: 0.39]
# [# features: 7701] [random attemps: 22] [prec: 0.5105] [rec: 0.4778] [F-score: 0.4936] [T: 0.47]
# [# features: 7701] [random attemps: 23] [prec: 0.4821] [rec: 0.4873] [F-score: 0.4847] [T: 0.73]
# [# features: 7701] [random attemps: 24] [prec: 0.5659] [rec: 0.5525] [F-score: 0.5591] [T: 0.47]
# [# features: 7701] [random attemps: 25] [prec: 0.5219] [rec: 0.5278] [F-score: 0.5248] [T: 0.31]
# [# features: 7701] [random attemps: 26] [prec: 0.4741] [rec: 0.4871] [F-score: 0.4805] [T: 0.27]
# [# features: 7701] [random attemps: 27] [prec: 0.5337] [rec: 0.5245] [F-score: 0.5291] [T: 0.27]
# [# features: 7701] [random attemps: 28] [prec: 0.5037] [rec: 0.5030] [F-score: 0.5034] [T: 0.31]
# [# features: 7701] [random attemps: 29] [prec: 0.4832] [rec: 0.4841] [F-score: 0.4836] [T: 0.32]
# [# features: 7701] [random attemps: 30] [prec: 0.5494] [rec: 0.5306] [F-score: 0.5398] [T: 0.31]
# [# features: 7701] [random attemps: 31] [prec: 0.5032] [rec: 0.4171] [F-score: 0.4562] [T: 0.27]
# [# features: 7701] [random attemps: 32] [prec: 0.5200] [rec: 0.5308] [F-score: 0.5254] [T: 0.39]
# [# features: 7701] [random attemps: 33] [prec: 0.4247] [rec: 0.4237] [F-score: 0.4242] [T: 0.37]
# [# features: 7701] [random attemps: 34] [prec: 0.4462] [rec: 0.4303] [F-score: 0.4381] [T: 0.43]
# [# features: 7701] [random attemps: 35] [prec: 0.5179] [rec: 0.5000] [F-score: 0.5088] [T: 0.45]
# [# features: 7701] [random attemps: 36] [prec: 0.4774] [rec: 0.4952] [F-score: 0.4861] [T: 0.38]
# [# features: 7701] [random attemps: 37] [prec: 0.5263] [rec: 0.5306] [F-score: 0.5284] [T: 0.29]
# [# features: 7701] [random attemps: 38] [prec: 0.5050] [rec: 0.5169] [F-score: 0.5109] [T: 0.36]
# [# features: 7701] [random attemps: 39] [prec: 0.4712] [rec: 0.4982] [F-score: 0.4843] [T: 0.38]
# [# features: 7701] [random attemps: 40] [prec: 0.4826] [rec: 0.4644] [F-score: 0.4733] [T: 0.52]
# [# features: 7701] [random attemps: 41] [prec: 0.5009] [rec: 0.4949] [F-score: 0.4979] [T: 0.65]
# [# features: 7701] [random attemps: 42] [prec: 0.4497] [rec: 0.4063] [F-score: 0.4269] [T: 0.86]
# [# features: 7701] [random attemps: 43] [prec: 0.4788] [rec: 0.5012] [F-score: 0.4897] [T: 0.37]
# [# features: 7701] [random attemps: 44] [prec: 0.5647] [rec: 0.5523] [F-score: 0.5584] [T: 0.26]
# [# features: 7701] [random attemps: 45] [prec: 0.5119] [rec: 0.5199] [F-score: 0.5159] [T: 0.37]
# [# features: 7701] [random attemps: 46] [prec: 0.4723] [rec: 0.4843] [F-score: 0.4782] [T: 0.36]
# [# features: 7701] [random attemps: 47] [prec: 0.5455] [rec: 0.5368] [F-score: 0.5411] [T: 0.36]
# [# features: 7701] [random attemps: 48] [prec: 0.5201] [rec: 0.5197] [F-score: 0.5199] [T: 0.34]
# [# features: 7701] [random attemps: 49] [prec: 0.4961] [rec: 0.5030] [F-score: 0.4996] [T: 0.54]
# [# features: 7702] [random attemps: 0] [prec: 0.4598] [rec: 0.4389] [F-score: 0.4491] [T: 0.45]
# [# features: 7702] [random attemps: 1] [prec: 0.4654] [rec: 0.4813] [F-score: 0.4732] [T: 0.43]
# [# features: 7702] [random attemps: 2] [prec: 0.4652] [rec: 0.4821] [F-score: 0.4735] [T: 0.46]
# [# features: 7702] [random attemps: 3] [prec: 0.5186] [rec: 0.5167] [F-score: 0.5176] [T: 0.37]
# [# features: 7702] [random attemps: 4] [prec: 0.5114] [rec: 0.4952] [F-score: 0.5032] [T: 0.37]
# [# features: 7702] [random attemps: 5] [prec: 0.5687] [rec: 0.5773] [F-score: 0.5730] [T: 0.36]
# [# features: 7702] [random attemps: 6] [prec: 0.5048] [rec: 0.5058] [F-score: 0.5053] [T: 0.36]
# [# features: 7702] [random attemps: 7] [prec: 0.5810] [rec: 0.5740] [F-score: 0.5775] [T: 0.60]
# [# features: 7702] [random attemps: 8] [prec: 0.4135] [rec: 0.4408] [F-score: 0.4267] [T: 0.43]
# [# features: 7702] [random attemps: 9] [prec: 0.4538] [rec: 0.4626] [F-score: 0.4581] [T: 0.46]
# [# features: 7702] [random attemps: 10] [prec: 0.5298] [rec: 0.5306] [F-score: 0.5302] [T: 0.51]
# [# features: 7702] [random attemps: 11] [prec: 0.5225] [rec: 0.5227] [F-score: 0.5226] [T: 0.40]
# [# features: 7702] [random attemps: 12] [prec: 0.4161] [rec: 0.4239] [F-score: 0.4200] [T: 0.27]
# [# features: 7702] [random attemps: 13] [prec: 0.5475] [rec: 0.5525] [F-score: 0.5500] [T: 0.33]
# [# features: 7702] [random attemps: 14] [prec: 0.3884] [rec: 0.4221] [F-score: 0.4045] [T: 0.35]
# [# features: 7702] [random attemps: 15] [prec: 0.5069] [rec: 0.4841] [F-score: 0.4952] [T: 0.36]
# [# features: 7702] [random attemps: 16] [prec: 0.5135] [rec: 0.5048] [F-score: 0.5092] [T: 0.33]
# [# features: 7702] [random attemps: 17] [prec: 0.5436] [rec: 0.5414] [F-score: 0.5425] [T: 0.53]
# [# features: 7702] [random attemps: 18] [prec: 0.5463] [rec: 0.5583] [F-score: 0.5522] [T: 0.54]
# [# features: 7702] [random attemps: 19] [prec: 0.4988] [rec: 0.5088] [F-score: 0.5038] [T: 0.59]
# [# features: 7702] [random attemps: 20] [prec: 0.4828] [rec: 0.4810] [F-score: 0.4819] [T: 0.54]
# [# features: 7702] [random attemps: 21] [prec: 0.4912] [rec: 0.4871] [F-score: 0.4891] [T: 0.40]
# [# features: 7702] [random attemps: 22] [prec: 0.4624] [rec: 0.4126] [F-score: 0.4361] [T: 0.39]
# [# features: 7702] [random attemps: 23] [prec: 0.4451] [rec: 0.4394] [F-score: 0.4422] [T: 0.66]
# [# features: 7702] [random attemps: 24] [prec: 0.5127] [rec: 0.5058] [F-score: 0.5092] [T: 0.57]
# [# features: 7702] [random attemps: 25] [prec: 0.5688] [rec: 0.5525] [F-score: 0.5605] [T: 0.39]
# [# features: 7702] [random attemps: 26] [prec: 0.5295] [rec: 0.5278] [F-score: 0.5286] [T: 0.47]
# [# features: 7702] [random attemps: 27] [prec: 0.4625] [rec: 0.4764] [F-score: 0.4694] [T: 0.70]
# [# features: 7702] [random attemps: 28] [prec: 0.5119] [rec: 0.5199] [F-score: 0.5159] [T: 0.91]
# [# features: 7702] [random attemps: 29] [prec: 0.3918] [rec: 0.4330] [F-score: 0.4114] [T: 0.86]
# [# features: 7702] [random attemps: 30] [prec: 0.4824] [rec: 0.4563] [F-score: 0.4690] [T: 0.38]
# [# features: 7702] [random attemps: 31] [prec: 0.4219] [rec: 0.4517] [F-score: 0.4363] [T: 0.48]
# [# features: 7702] [random attemps: 32] [prec: 0.5227] [rec: 0.5028] [F-score: 0.5125] [T: 0.52]
# [# features: 7702] [random attemps: 33] [prec: 0.4604] [rec: 0.4644] [F-score: 0.4624] [T: 0.38]
# [# features: 7702] [random attemps: 34] [prec: 0.4762] [rec: 0.4873] [F-score: 0.4817] [T: 0.61]
# [# features: 7702] [random attemps: 35] [prec: 0.5167] [rec: 0.5197] [F-score: 0.5182] [T: 0.54]
# [# features: 7702] [random attemps: 36] [prec: 0.5186] [rec: 0.4389] [F-score: 0.4754] [T: 0.77]
# [# features: 7702] [random attemps: 37] [prec: 0.5353] [rec: 0.4979] [F-score: 0.5159] [T: 1.11]
# [# features: 7702] [random attemps: 38] [prec: 0.4823] [rec: 0.4810] [F-score: 0.4817] [T: 0.64]
# [# features: 7702] [random attemps: 39] [prec: 0.4962] [rec: 0.4952] [F-score: 0.4957] [T: 0.57]
# [# features: 7702] [random attemps: 40] [prec: 0.4925] [rec: 0.4979] [F-score: 0.4952] [T: 0.85]
# [# features: 7702] [random attemps: 41] [prec: 0.5138] [rec: 0.5058] [F-score: 0.5098] [T: 0.84]
# [# features: 7702] [random attemps: 42] [prec: 0.5372] [rec: 0.5220] [F-score: 0.5295] [T: 0.95]
# [# features: 7702] [random attemps: 43] [prec: 0.4773] [rec: 0.4813] [F-score: 0.4793] [T: 0.38]
# [# features: 7702] [random attemps: 44] [prec: 0.4663] [rec: 0.4653] [F-score: 0.4658] [T: 0.36]
# [# features: 7702] [random attemps: 45] [prec: 0.4325] [rec: 0.4487] [F-score: 0.4404] [T: 0.48]
# [# features: 7702] [random attemps: 46] [prec: 0.4593] [rec: 0.4595] [F-score: 0.4594] [T: 0.57]
# [# features: 7702] [random attemps: 47] [prec: 0.5539] [rec: 0.5664] [F-score: 0.5601] [T: 0.51]
# [# features: 7702] [random attemps: 48] [prec: 0.4909] [rec: 0.5091] [F-score: 0.4998] [T: 0.57]
# [# features: 7702] [random attemps: 49] [prec: 0.4981] [rec: 0.5030] [F-score: 0.5005] [T: 0.38]
# [# features: 7703] [random attemps: 0] [prec: 0.5102] [rec: 0.5227] [F-score: 0.5164] [T: 0.28]
# [# features: 7703] [random attemps: 1] [prec: 0.4146] [rec: 0.4017] [F-score: 0.4080] [T: 0.35]
# [# features: 7703] [random attemps: 2] [prec: 0.5194] [rec: 0.5091] [F-score: 0.5142] [T: 0.37]
# [# features: 7703] [random attemps: 3] [prec: 0.5015] [rec: 0.5091] [F-score: 0.5052] [T: 0.39]
# [# features: 7703] [random attemps: 4] [prec: 0.5559] [rec: 0.5604] [F-score: 0.5582] [T: 0.33]
# [# features: 7703] [random attemps: 5] [prec: 0.5441] [rec: 0.5525] [F-score: 0.5483] [T: 0.35]
# [# features: 7703] [random attemps: 6] [prec: 0.5001] [rec: 0.4829] [F-score: 0.4913] [T: 0.38]
# [# features: 7703] [random attemps: 7] [prec: 0.5369] [rec: 0.5417] [F-score: 0.5393] [T: 0.38]
# [# features: 7703] [random attemps: 8] [prec: 0.5041] [rec: 0.4891] [F-score: 0.4965] [T: 0.33]
# [# features: 7703] [random attemps: 9] [prec: 0.6763] [rec: 0.5319] [F-score: 0.5954] [T: 0.33]
# [# features: 7703] [random attemps: 10] [prec: 0.4423] [rec: 0.4421] [F-score: 0.4422] [T: 0.42]
# [# features: 7703] [random attemps: 11] [prec: 0.5595] [rec: 0.5634] [F-score: 0.5614] [T: 0.56]
# [# features: 7703] [random attemps: 12] [prec: 0.4405] [rec: 0.4626] [F-score: 0.4512] [T: 0.48]
# [# features: 7703] [random attemps: 13] [prec: 0.4561] [rec: 0.4873] [F-score: 0.4712] [T: 0.92]
# [# features: 7703] [random attemps: 14] [prec: 0.4441] [rec: 0.4686] [F-score: 0.4560] [T: 0.62]
# [# features: 7703] [random attemps: 15] [prec: 0.4741] [rec: 0.4732] [F-score: 0.4736] [T: 0.41]
# [# features: 7703] [random attemps: 16] [prec: 0.5114] [rec: 0.5199] [F-score: 0.5156] [T: 0.42]
# [# features: 7703] [random attemps: 17] [prec: 0.5697] [rec: 0.5682] [F-score: 0.5690] [T: 0.42]
# [# features: 7703] [random attemps: 18] [prec: 0.4146] [rec: 0.4297] [F-score: 0.4220] [T: 0.47]
# [# features: 7703] [random attemps: 19] [prec: 0.4988] [rec: 0.5060] [F-score: 0.5024] [T: 0.45]
# [# features: 7703] [random attemps: 20] [prec: 0.4890] [rec: 0.4734] [F-score: 0.4811] [T: 0.41]
# [# features: 7703] [random attemps: 21] [prec: 0.5012] [rec: 0.4952] [F-score: 0.4982] [T: 0.38]
# [# features: 7703] [random attemps: 22] [prec: 0.4944] [rec: 0.5060] [F-score: 0.5001] [T: 0.40]
# [# features: 7703] [random attemps: 23] [prec: 0.6757] [rec: 0.6175] [F-score: 0.6453] [T: 0.39]
# [# features: 7703] [random attemps: 24] [prec: 0.4951] [rec: 0.4623] [F-score: 0.4782] [T: 0.53]
# [# features: 7703] [random attemps: 25] [prec: 0.4935] [rec: 0.4949] [F-score: 0.4942] [T: 0.47]
# [# features: 7703] [random attemps: 26] [prec: 0.4222] [rec: 0.4434] [F-score: 0.4325] [T: 0.54]
# [# features: 7703] [random attemps: 27] [prec: 0.5905] [rec: 0.5990] [F-score: 0.5948] [T: 0.51]
# [# features: 7703] [random attemps: 28] [prec: 0.5146] [rec: 0.4982] [F-score: 0.5063] [T: 0.37]
# [# features: 7703] [random attemps: 29] [prec: 0.5482] [rec: 0.5525] [F-score: 0.5503] [T: 0.41]
# [# features: 7703] [random attemps: 30] [prec: 0.5482] [rec: 0.5354] [F-score: 0.5417] [T: 0.37]
# [# features: 7703] [random attemps: 31] [prec: 0.4659] [rec: 0.4343] [F-score: 0.4495] [T: 0.40]
# [# features: 7703] [random attemps: 32] [prec: 0.6255] [rec: 0.5930] [F-score: 0.6088] [T: 0.42]
# [# features: 7703] [random attemps: 33] [prec: 0.4592] [rec: 0.4530] [F-score: 0.4561] [T: 0.36]
# [# features: 7703] [random attemps: 34] [prec: 0.3912] [rec: 0.4158] [F-score: 0.4031] [T: 0.38]
# [# features: 7703] [random attemps: 35] [prec: 0.4762] [rec: 0.4903] [F-score: 0.4831] [T: 0.35]
# [# features: 7703] [random attemps: 36] [prec: 0.5218] [rec: 0.5197] [F-score: 0.5207] [T: 0.36]
# [# features: 7703] [random attemps: 37] [prec: 0.5258] [rec: 0.5308] [F-score: 0.5283] [T: 0.37]
# [# features: 7703] [random attemps: 38] [prec: 0.5021] [rec: 0.5169] [F-score: 0.5094] [T: 0.45]
# [# features: 7703] [random attemps: 39] [prec: 0.5553] [rec: 0.5167] [F-score: 0.5353] [T: 0.44]
# [# features: 7703] [random attemps: 40] [prec: 0.5408] [rec: 0.5417] [F-score: 0.5412] [T: 0.43]
# [# features: 7703] [random attemps: 41] [prec: 0.5242] [rec: 0.5447] [F-score: 0.5343] [T: 0.47]
# [# features: 7703] [random attemps: 42] [prec: 0.5189] [rec: 0.5278] [F-score: 0.5233] [T: 0.41]
# [# features: 7703] [random attemps: 43] [prec: 0.4946] [rec: 0.5229] [F-score: 0.5084] [T: 0.33]
# [# features: 7703] [random attemps: 44] [prec: 0.5272] [rec: 0.5308] [F-score: 0.5290] [T: 0.32]
# [# features: 7703] [random attemps: 45] [prec: 0.4426] [rec: 0.4484] [F-score: 0.4455] [T: 0.32]
# [# features: 7703] [random attemps: 46] [prec: 0.5375] [rec: 0.4988] [F-score: 0.5174] [T: 0.35]
# [# features: 7703] [random attemps: 47] [prec: 0.5258] [rec: 0.5306] [F-score: 0.5282] [T: 0.30]
# [# features: 7703] [random attemps: 48] [prec: 0.5481] [rec: 0.5248] [F-score: 0.5362] [T: 0.31]
# [# features: 7703] [random attemps: 49] [prec: 0.5590] [rec: 0.5356] [F-score: 0.5471] [T: 0.31]
# [# features: 7704] [random attemps: 0] [prec: 0.5145] [rec: 0.5030] [F-score: 0.5087] [T: 0.30]
# [# features: 7704] [random attemps: 1] [prec: 0.5169] [rec: 0.5169] [F-score: 0.5169] [T: 0.31]
# [# features: 7704] [random attemps: 2] [prec: 0.4993] [rec: 0.4595] [F-score: 0.4786] [T: 0.30]
# [# features: 7704] [random attemps: 3] [prec: 0.5583] [rec: 0.5523] [F-score: 0.5553] [T: 0.33]
# [# features: 7704] [random attemps: 4] [prec: 0.5907] [rec: 0.5821] [F-score: 0.5864] [T: 0.33]
# [# features: 7704] [random attemps: 5] [prec: 0.5208] [rec: 0.5139] [F-score: 0.5173] [T: 0.33]
# [# features: 7704] [random attemps: 6] [prec: 0.4448] [rec: 0.4545] [F-score: 0.4496] [T: 0.36]
# [# features: 7704] [random attemps: 7] [prec: 0.4992] [rec: 0.4831] [F-score: 0.4910] [T: 0.34]
# [# features: 7704] [random attemps: 8] [prec: 0.4863] [rec: 0.4979] [F-score: 0.4921] [T: 0.25]
# [# features: 7704] [random attemps: 9] [prec: 0.4947] [rec: 0.5060] [F-score: 0.5003] [T: 0.25]
# [# features: 7704] [random attemps: 10] [prec: 0.4840] [rec: 0.4982] [F-score: 0.4910] [T: 0.26]
# [# features: 7704] [random attemps: 11] [prec: 0.4913] [rec: 0.5030] [F-score: 0.4971] [T: 0.28]
# [# features: 7704] [random attemps: 12] [prec: 0.4417] [rec: 0.4315] [F-score: 0.4365] [T: 0.28]
# [# features: 7704] [random attemps: 13] [prec: 0.5411] [rec: 0.5356] [F-score: 0.5383] [T: 0.27]
# [# features: 7704] [random attemps: 14] [prec: 0.4641] [rec: 0.4843] [F-score: 0.4740] [T: 0.26]
# [# features: 7704] [random attemps: 15] [prec: 0.5831] [rec: 0.5743] [F-score: 0.5787] [T: 0.26]
# [# features: 7704] [random attemps: 16] [prec: 0.4831] [rec: 0.4810] [F-score: 0.4821] [T: 0.28]
# [# features: 7704] [random attemps: 17] [prec: 0.4759] [rec: 0.4662] [F-score: 0.4710] [T: 0.24]
# [# features: 7704] [random attemps: 18] [prec: 0.4625] [rec: 0.4667] [F-score: 0.4645] [T: 0.25]
# [# features: 7704] [random attemps: 19] [prec: 0.4389] [rec: 0.4656] [F-score: 0.4518] [T: 0.25]
# [# features: 7704] [random attemps: 20] [prec: 0.5782] [rec: 0.5743] [F-score: 0.5762] [T: 0.24]
# [# features: 7704] [random attemps: 21] [prec: 0.5593] [rec: 0.5664] [F-score: 0.5628] [T: 0.33]
# [# features: 7704] [random attemps: 22] [prec: 0.4458] [rec: 0.4408] [F-score: 0.4433] [T: 0.28]
# [# features: 7704] [random attemps: 23] [prec: 0.4716] [rec: 0.4843] [F-score: 0.4779] [T: 0.36]
# [# features: 7704] [random attemps: 24] [prec: 0.4076] [rec: 0.4128] [F-score: 0.4102] [T: 0.36]
# [# features: 7704] [random attemps: 25] [prec: 0.6340] [rec: 0.6238] [F-score: 0.6289] [T: 0.31]
# [# features: 7704] [random attemps: 26] [prec: 0.4990] [rec: 0.4843] [F-score: 0.4915] [T: 0.29]
# [# features: 7704] [random attemps: 27] [prec: 0.4675] [rec: 0.4873] [F-score: 0.4772] [T: 0.28]
# [# features: 7704] [random attemps: 28] [prec: 0.5330] [rec: 0.5386] [F-score: 0.5358] [T: 0.25]
# [# features: 7704] [random attemps: 29] [prec: 0.4858] [rec: 0.4783] [F-score: 0.4820] [T: 0.27]
# [# features: 7704] [random attemps: 30] [prec: 0.5581] [rec: 0.5493] [F-score: 0.5537] [T: 0.32]
# [# features: 7704] [random attemps: 31] [prec: 0.4809] [rec: 0.4780] [F-score: 0.4794] [T: 0.27]
# [# features: 7704] [random attemps: 32] [prec: 0.4633] [rec: 0.4873] [F-score: 0.4750] [T: 0.24]
# [# features: 7704] [random attemps: 33] [prec: 0.5368] [rec: 0.5139] [F-score: 0.5251] [T: 0.25]
# [# features: 7704] [random attemps: 34] [prec: 0.5294] [rec: 0.5417] [F-score: 0.5354] [T: 0.25]
# [# features: 7704] [random attemps: 35] [prec: 0.5162] [rec: 0.5308] [F-score: 0.5234] [T: 0.29]
# [# features: 7704] [random attemps: 36] [prec: 0.5160] [rec: 0.4921] [F-score: 0.5038] [T: 0.25]
# [# features: 7704] [random attemps: 37] [prec: 0.4473] [rec: 0.4505] [F-score: 0.4489] [T: 0.29]
# [# features: 7704] [random attemps: 38] [prec: 0.4992] [rec: 0.4752] [F-score: 0.4869] [T: 0.31]
# [# features: 7704] [random attemps: 39] [prec: 0.4855] [rec: 0.4921] [F-score: 0.4888] [T: 0.28]
# [# features: 7704] [random attemps: 40] [prec: 0.4647] [rec: 0.4331] [F-score: 0.4484] [T: 0.36]
# [# features: 7704] [random attemps: 41] [prec: 0.5950] [rec: 0.5849] [F-score: 0.5899] [T: 0.32]
# [# features: 7704] [random attemps: 42] [prec: 0.4663] [rec: 0.4702] [F-score: 0.4682] [T: 0.30]
# [# features: 7704] [random attemps: 43] [prec: 0.5723] [rec: 0.5127] [F-score: 0.5409] [T: 0.27]
# [# features: 7704] [random attemps: 44] [prec: 0.4659] [rec: 0.4815] [F-score: 0.4736] [T: 0.28]
# [# features: 7704] [random attemps: 45] [prec: 0.4659] [rec: 0.4732] [F-score: 0.4695] [T: 0.28]
# [# features: 7704] [random attemps: 46] [prec: 0.5458] [rec: 0.5525] [F-score: 0.5492] [T: 0.26]
# [# features: 7704] [random attemps: 47] [prec: 0.5261] [rec: 0.5338] [F-score: 0.5299] [T: 0.25]
# [# features: 7704] [random attemps: 48] [prec: 0.6167] [rec: 0.6238] [F-score: 0.6203] [T: 0.28]
# [# features: 7704] [random attemps: 49] [prec: 0.5526] [rec: 0.5525] [F-score: 0.5526] [T: 0.26]
# [# features: 7705] [random attemps: 0] [prec: 0.5543] [rec: 0.5523] [F-score: 0.5533] [T: 0.26]
# [# features: 7705] [random attemps: 1] [prec: 0.4460] [rec: 0.4565] [F-score: 0.4512] [T: 0.27]
# [# features: 7705] [random attemps: 2] [prec: 0.5005] [rec: 0.5058] [F-score: 0.5031] [T: 0.27]
# [# features: 7705] [random attemps: 3] [prec: 0.6585] [rec: 0.5101] [F-score: 0.5749] [T: 0.27]
# [# features: 7705] [random attemps: 4] [prec: 0.5287] [rec: 0.5101] [F-score: 0.5193] [T: 0.33]
# [# features: 7705] [random attemps: 5] [prec: 0.4951] [rec: 0.5058] [F-score: 0.5004] [T: 0.32]
# [# features: 7705] [random attemps: 6] [prec: 0.4941] [rec: 0.4921] [F-score: 0.4931] [T: 0.32]
# [# features: 7705] [random attemps: 7] [prec: 0.4742] [rec: 0.4611] [F-score: 0.4675] [T: 0.34]
# [# features: 7705] [random attemps: 8] [prec: 0.5158] [rec: 0.5139] [F-score: 0.5148] [T: 0.35]
# [# features: 7705] [random attemps: 9] [prec: 0.4647] [rec: 0.4734] [F-score: 0.4690] [T: 0.30]
# [# features: 7705] [random attemps: 10] [prec: 0.4597] [rec: 0.4653] [F-score: 0.4625] [T: 0.29]
# [# features: 7705] [random attemps: 11] [prec: 0.4819] [rec: 0.4861] [F-score: 0.4840] [T: 0.25]
# [# features: 7705] [random attemps: 12] [prec: 0.4485] [rec: 0.4517] [F-score: 0.4501] [T: 0.29]
# [# features: 7705] [random attemps: 13] [prec: 0.5144] [rec: 0.5167] [F-score: 0.5155] [T: 0.28]
# [# features: 7705] [random attemps: 14] [prec: 0.4960] [rec: 0.4940] [F-score: 0.4950] [T: 0.25]
# [# features: 7705] [random attemps: 15] [prec: 0.4823] [rec: 0.4952] [F-score: 0.4886] [T: 0.28]
# [# features: 7705] [random attemps: 16] [prec: 0.4981] [rec: 0.4949] [F-score: 0.4965] [T: 0.29]
# [# features: 7705] [random attemps: 17] [prec: 0.5766] [rec: 0.5632] [F-score: 0.5698] [T: 0.38]
# [# features: 7705] [random attemps: 18] [prec: 0.4978] [rec: 0.4982] [F-score: 0.4980] [T: 0.31]
# [# features: 7705] [random attemps: 19] [prec: 0.5426] [rec: 0.5356] [F-score: 0.5391] [T: 0.30]
# [# features: 7705] [random attemps: 20] [prec: 0.5660] [rec: 0.5245] [F-score: 0.5445] [T: 0.33]
# [# features: 7705] [random attemps: 21] [prec: 0.4363] [rec: 0.4194] [F-score: 0.4277] [T: 0.33]
# [# features: 7705] [random attemps: 22] [prec: 0.5014] [rec: 0.4984] [F-score: 0.4999] [T: 0.32]
# [# features: 7705] [random attemps: 23] [prec: 0.5307] [rec: 0.5384] [F-score: 0.5345] [T: 0.34]
# [# features: 7705] [random attemps: 24] [prec: 0.4374] [rec: 0.4686] [F-score: 0.4525] [T: 0.34]
# [# features: 7705] [random attemps: 25] [prec: 0.4237] [rec: 0.4408] [F-score: 0.4321] [T: 0.31]
# [# features: 7705] [random attemps: 26] [prec: 0.4979] [rec: 0.5229] [F-score: 0.5101] [T: 0.27]
# [# features: 7705] [random attemps: 27] [prec: 0.6142] [rec: 0.5849] [F-score: 0.5992] [T: 0.27]
# [# features: 7705] [random attemps: 28] [prec: 0.4527] [rec: 0.4674] [F-score: 0.4599] [T: 0.25]
# [# features: 7705] [random attemps: 29] [prec: 0.6379] [rec: 0.6208] [F-score: 0.6292] [T: 0.27]
# [# features: 7705] [random attemps: 30] [prec: 0.4727] [rec: 0.4692] [F-score: 0.4709] [T: 0.29]
# [# features: 7705] [random attemps: 31] [prec: 0.5474] [rec: 0.5248] [F-score: 0.5358] [T: 0.30]
# [# features: 7705] [random attemps: 32] [prec: 0.5730] [rec: 0.5574] [F-score: 0.5651] [T: 0.27]
# [# features: 7705] [random attemps: 33] [prec: 0.5393] [rec: 0.5556] [F-score: 0.5473] [T: 0.29]
# [# features: 7705] [random attemps: 34] [prec: 0.6161] [rec: 0.5958] [F-score: 0.6058] [T: 0.26]
# [# features: 7705] [random attemps: 35] [prec: 0.6141] [rec: 0.6099] [F-score: 0.6120] [T: 0.25]
# [# features: 7705] [random attemps: 36] [prec: 0.4267] [rec: 0.4517] [F-score: 0.4389] [T: 0.27]
# [# features: 7705] [random attemps: 37] [prec: 0.4061] [rec: 0.4110] [F-score: 0.4085] [T: 0.27]
# [# features: 7705] [random attemps: 38] [prec: 0.5163] [rec: 0.4919] [F-score: 0.5038] [T: 0.26]
# [# features: 7705] [random attemps: 39] [prec: 0.5484] [rec: 0.5106] [F-score: 0.5289] [T: 0.26]
# [# features: 7705] [random attemps: 40] [prec: 0.4455] [rec: 0.4484] [F-score: 0.4470] [T: 0.27]
# [# features: 7705] [random attemps: 41] [prec: 0.4998] [rec: 0.4593] [F-score: 0.4787] [T: 0.31]
# [# features: 7705] [random attemps: 42] [prec: 0.5445] [rec: 0.5556] [F-score: 0.5500] [T: 0.32]
# [# features: 7705] [random attemps: 43] [prec: 0.4912] [rec: 0.5091] [F-score: 0.5000] [T: 0.33]
# [# features: 7705] [random attemps: 44] [prec: 0.4216] [rec: 0.4348] [F-score: 0.4281] [T: 0.37]
# [# features: 7705] [random attemps: 45] [prec: 0.5602] [rec: 0.5604] [F-score: 0.5603] [T: 0.31]
# [# features: 7705] [random attemps: 46] [prec: 0.4823] [rec: 0.4783] [F-score: 0.4803] [T: 0.29]
# [# features: 7705] [random attemps: 47] [prec: 0.5556] [rec: 0.5664] [F-score: 0.5610] [T: 0.29]
# [# features: 7705] [random attemps: 48] [prec: 0.6195] [rec: 0.5851] [F-score: 0.6018] [T: 0.27]
# [# features: 7705] [random attemps: 49] [prec: 0.5561] [rec: 0.5386] [F-score: 0.5472] [T: 0.24]
# [# features: 7706] [random attemps: 0] [prec: 0.3831] [rec: 0.4074] [F-score: 0.3949] [T: 0.27]
# [# features: 7706] [random attemps: 1] [prec: 0.5907] [rec: 0.5849] [F-score: 0.5878] [T: 0.26]
# [# features: 7706] [random attemps: 2] [prec: 0.4802] [rec: 0.4810] [F-score: 0.4806] [T: 0.25]
# [# features: 7706] [random attemps: 3] [prec: 0.5411] [rec: 0.5444] [F-score: 0.5427] [T: 0.26]
# [# features: 7706] [random attemps: 4] [prec: 0.5583] [rec: 0.5634] [F-score: 0.5608] [T: 0.26]
# [# features: 7706] [random attemps: 5] [prec: 0.3988] [rec: 0.4300] [F-score: 0.4138] [T: 0.27]
# [# features: 7706] [random attemps: 6] [prec: 0.5644] [rec: 0.5386] [F-score: 0.5512] [T: 0.33]
# [# features: 7706] [random attemps: 7] [prec: 0.5134] [rec: 0.5058] [F-score: 0.5096] [T: 0.31]
# [# features: 7706] [random attemps: 8] [prec: 0.4939] [rec: 0.4748] [F-score: 0.4842] [T: 0.30]
# [# features: 7706] [random attemps: 9] [prec: 0.5406] [rec: 0.5275] [F-score: 0.5340] [T: 0.33]
# [# features: 7706] [random attemps: 10] [prec: 0.5304] [rec: 0.4588] [F-score: 0.4920] [T: 0.31]
# [# features: 7706] [random attemps: 11] [prec: 0.4562] [rec: 0.4623] [F-score: 0.4593] [T: 0.34]
# [# features: 7706] [random attemps: 12] [prec: 0.5205] [rec: 0.5217] [F-score: 0.5211] [T: 0.29]
# [# features: 7706] [random attemps: 13] [prec: 0.4506] [rec: 0.4873] [F-score: 0.4683] [T: 0.27]
# [# features: 7706] [random attemps: 14] [prec: 0.5290] [rec: 0.5278] [F-score: 0.5284] [T: 0.26]
# [# features: 7706] [random attemps: 15] [prec: 0.4790] [rec: 0.4813] [F-score: 0.4801] [T: 0.25]
# [# features: 7706] [random attemps: 16] [prec: 0.4772] [rec: 0.4702] [F-score: 0.4736] [T: 0.25]
# [# features: 7706] [random attemps: 17] [prec: 0.5493] [rec: 0.5525] [F-score: 0.5509] [T: 0.27]
# [# features: 7706] [random attemps: 18] [prec: 0.4535] [rec: 0.4734] [F-score: 0.4632] [T: 0.26]
# [# features: 7706] [random attemps: 19] [prec: 0.6202] [rec: 0.5849] [F-score: 0.6020] [T: 0.27]
# [# features: 7706] [random attemps: 20] [prec: 0.5006] [rec: 0.5199] [F-score: 0.5101] [T: 0.26]
# [# features: 7706] [random attemps: 21] [prec: 0.5971] [rec: 0.5025] [F-score: 0.5458] [T: 0.27]
# [# features: 7706] [random attemps: 22] [prec: 0.4894] [rec: 0.4843] [F-score: 0.4868] [T: 0.29]
# [# features: 7706] [random attemps: 23] [prec: 0.5335] [rec: 0.5308] [F-score: 0.5322] [T: 0.27]
# [# features: 7706] [random attemps: 24] [prec: 0.4903] [rec: 0.4952] [F-score: 0.4927] [T: 0.27]
# [# features: 7706] [random attemps: 25] [prec: 0.5942] [rec: 0.5990] [F-score: 0.5966] [T: 0.32]
# [# features: 7706] [random attemps: 26] [prec: 0.6199] [rec: 0.6236] [F-score: 0.6217] [T: 0.30]
# [# features: 7706] [random attemps: 27] [prec: 0.4954] [rec: 0.5088] [F-score: 0.5020] [T: 0.30]
# [# features: 7706] [random attemps: 28] [prec: 0.4175] [rec: 0.4082] [F-score: 0.4128] [T: 0.34]
# [# features: 7706] [random attemps: 29] [prec: 0.4914] [rec: 0.5091] [F-score: 0.5001] [T: 0.33]
# [# features: 7706] [random attemps: 30] [prec: 0.5467] [rec: 0.5525] [F-score: 0.5496] [T: 0.28]
# [# features: 7706] [random attemps: 31] [prec: 0.4945] [rec: 0.5088] [F-score: 0.5015] [T: 0.26]
# [# features: 7706] [random attemps: 32] [prec: 0.5257] [rec: 0.5060] [F-score: 0.5157] [T: 0.26]
# [# features: 7706] [random attemps: 33] [prec: 0.4412] [rec: 0.4595] [F-score: 0.4502] [T: 0.26]
# [# features: 7706] [random attemps: 34] [prec: 0.4420] [rec: 0.4656] [F-score: 0.4535] [T: 0.27]
# [# features: 7706] [random attemps: 35] [prec: 0.4873] [rec: 0.5091] [F-score: 0.4980] [T: 0.27]
# [# features: 7706] [random attemps: 36] [prec: 0.4525] [rec: 0.4656] [F-score: 0.4590] [T: 0.25]
# [# features: 7706] [random attemps: 37] [prec: 0.5067] [rec: 0.5121] [F-score: 0.5094] [T: 0.24]
# [# features: 7706] [random attemps: 38] [prec: 0.5366] [rec: 0.4856] [F-score: 0.5099] [T: 0.26]
# [# features: 7706] [random attemps: 39] [prec: 0.5053] [rec: 0.5060] [F-score: 0.5057] [T: 0.27]
# [# features: 7706] [random attemps: 40] [prec: 0.6131] [rec: 0.5960] [F-score: 0.6044] [T: 0.25]
# [# features: 7706] [random attemps: 41] [prec: 0.5859] [rec: 0.5791] [F-score: 0.5825] [T: 0.26]
# [# features: 7706] [random attemps: 42] [prec: 0.4462] [rec: 0.4502] [F-score: 0.4482] [T: 0.30]
# [# features: 7706] [random attemps: 43] [prec: 0.5191] [rec: 0.5199] [F-score: 0.5195] [T: 0.39]
# [# features: 7706] [random attemps: 44] [prec: 0.5225] [rec: 0.5167] [F-score: 0.5196] [T: 0.30]
# [# features: 7706] [random attemps: 45] [prec: 0.6020] [rec: 0.5849] [F-score: 0.5933] [T: 0.30]
# [# features: 7706] [random attemps: 46] [prec: 0.5212] [rec: 0.5136] [F-score: 0.5174] [T: 0.34]
# [# features: 7706] [random attemps: 47] [prec: 0.4707] [rec: 0.4626] [F-score: 0.4666] [T: 0.31]
# [# features: 7706] [random attemps: 48] [prec: 0.6620] [rec: 0.5071] [F-score: 0.5743] [T: 0.24]
# [# features: 7706] [random attemps: 49] [prec: 0.5250] [rec: 0.5171] [F-score: 0.5211] [T: 0.26]
# [# features: 7707] [random attemps: 0] [prec: 0.4697] [rec: 0.4702] [F-score: 0.4700] [T: 0.26]
# [# features: 7707] [random attemps: 1] [prec: 0.4308] [rec: 0.4366] [F-score: 0.4337] [T: 0.26]
# [# features: 7707] [random attemps: 2] [prec: 0.7083] [rec: 0.6112] [F-score: 0.6562] [T: 0.26]
# [# features: 7707] [random attemps: 3] [prec: 0.5791] [rec: 0.5773] [F-score: 0.5782] [T: 0.25]
# [# features: 7707] [random attemps: 4] [prec: 0.5344] [rec: 0.5248] [F-score: 0.5296] [T: 0.27]
# [# features: 7707] [random attemps: 5] [prec: 0.4528] [rec: 0.4734] [F-score: 0.4629] [T: 0.28]
# [# features: 7707] [random attemps: 6] [prec: 0.4047] [rec: 0.3820] [F-score: 0.3930] [T: 0.26]
# [# features: 7707] [random attemps: 7] [prec: 0.5975] [rec: 0.5604] [F-score: 0.5783] [T: 0.28]
# [# features: 7707] [random attemps: 8] [prec: 0.4392] [rec: 0.4484] [F-score: 0.4438] [T: 0.27]
# [# features: 7707] [random attemps: 9] [prec: 0.4327] [rec: 0.4341] [F-score: 0.4334] [T: 0.28]
# [# features: 7707] [random attemps: 10] [prec: 0.5359] [rec: 0.5447] [F-score: 0.5403] [T: 0.27]
# [# features: 7707] [random attemps: 11] [prec: 0.4399] [rec: 0.4267] [F-score: 0.4332] [T: 0.33]
# [# features: 7707] [random attemps: 12] [prec: 0.4939] [rec: 0.5060] [F-score: 0.4999] [T: 0.35]
# [# features: 7707] [random attemps: 13] [prec: 0.4360] [rec: 0.4457] [F-score: 0.4408] [T: 0.36]
# [# features: 7707] [random attemps: 14] [prec: 0.4855] [rec: 0.4873] [F-score: 0.4864] [T: 0.35]
# [# features: 7707] [random attemps: 15] [prec: 0.4945] [rec: 0.5088] [F-score: 0.5015] [T: 0.33]
# [# features: 7707] [random attemps: 16] [prec: 0.5467] [rec: 0.5202] [F-score: 0.5331] [T: 0.27]
# [# features: 7707] [random attemps: 17] [prec: 0.5680] [rec: 0.5634] [F-score: 0.5657] [T: 0.28]
# [# features: 7707] [random attemps: 18] [prec: 0.4964] [rec: 0.4780] [F-score: 0.4870] [T: 0.27]
# [# features: 7707] [random attemps: 19] [prec: 0.5331] [rec: 0.5417] [F-score: 0.5374] [T: 0.27]
# [# features: 7707] [random attemps: 20] [prec: 0.5351] [rec: 0.5308] [F-score: 0.5329] [T: 0.28]
# [# features: 7707] [random attemps: 21] [prec: 0.4499] [rec: 0.4626] [F-score: 0.4561] [T: 0.28]
# [# features: 7707] [random attemps: 22] [prec: 0.4937] [rec: 0.4871] [F-score: 0.4904] [T: 0.27]
# [# features: 7707] [random attemps: 23] [prec: 0.5071] [rec: 0.5197] [F-score: 0.5133] [T: 0.27]
# [# features: 7707] [random attemps: 24] [prec: 0.7319] [rec: 0.6006] [F-score: 0.6598] [T: 0.26]
# [# features: 7707] [random attemps: 25] [prec: 0.5998] [rec: 0.6018] [F-score: 0.6008] [T: 0.25]
# [# features: 7707] [random attemps: 26] [prec: 0.4127] [rec: 0.4086] [F-score: 0.4106] [T: 0.28]
# [# features: 7707] [random attemps: 27] [prec: 0.4604] [rec: 0.4621] [F-score: 0.4612] [T: 0.30]
# [# features: 7707] [random attemps: 28] [prec: 0.4503] [rec: 0.4535] [F-score: 0.4519] [T: 0.33]
# [# features: 7707] [random attemps: 29] [prec: 0.4307] [rec: 0.4626] [F-score: 0.4460] [T: 0.30]
# [# features: 7707] [random attemps: 30] [prec: 0.4940] [rec: 0.4810] [F-score: 0.4875] [T: 0.31]
# [# features: 7707] [random attemps: 31] [prec: 0.3872] [rec: 0.3984] [F-score: 0.3927] [T: 0.35]
# [# features: 7707] [random attemps: 32] [prec: 0.5136] [rec: 0.5169] [F-score: 0.5153] [T: 0.35]
# [# features: 7707] [random attemps: 33] [prec: 0.5075] [rec: 0.4889] [F-score: 0.4980] [T: 0.27]
# [# features: 7707] [random attemps: 34] [prec: 0.4846] [rec: 0.4921] [F-score: 0.4883] [T: 0.27]
# [# features: 7707] [random attemps: 35] [prec: 0.5669] [rec: 0.5713] [F-score: 0.5691] [T: 0.30]
# [# features: 7707] [random attemps: 36] [prec: 0.5294] [rec: 0.5417] [F-score: 0.5354] [T: 0.26]
# [# features: 7707] [random attemps: 37] [prec: 0.5539] [rec: 0.5664] [F-score: 0.5601] [T: 0.26]
# [# features: 7707] [random attemps: 38] [prec: 0.5672] [rec: 0.5465] [F-score: 0.5567] [T: 0.28]
# [# features: 7707] [random attemps: 39] [prec: 0.4577] [rec: 0.4484] [F-score: 0.4530] [T: 0.25]
# [# features: 7707] [random attemps: 40] [prec: 0.5566] [rec: 0.4591] [F-score: 0.5032] [T: 0.26]
# [# features: 7707] [random attemps: 41] [prec: 0.5203] [rec: 0.5028] [F-score: 0.5114] [T: 0.27]
# [# features: 7707] [random attemps: 42] [prec: 0.4959] [rec: 0.5012] [F-score: 0.4986] [T: 0.28]
# [# features: 7707] [random attemps: 43] [prec: 0.5279] [rec: 0.5030] [F-score: 0.5152] [T: 0.28]
# [# features: 7707] [random attemps: 44] [prec: 0.6085] [rec: 0.5958] [F-score: 0.6021] [T: 0.26]
# [# features: 7707] [random attemps: 45] [prec: 0.4246] [rec: 0.4376] [F-score: 0.4310] [T: 0.34]
# [# features: 7707] [random attemps: 46] [prec: 0.5271] [rec: 0.5386] [F-score: 0.5328] [T: 0.32]
# [# features: 7707] [random attemps: 47] [prec: 0.4895] [rec: 0.4921] [F-score: 0.4908] [T: 0.35]
# [# features: 7707] [random attemps: 48] [prec: 0.5868] [rec: 0.5604] [F-score: 0.5733] [T: 0.32]
# [# features: 7707] [random attemps: 49] [prec: 0.5319] [rec: 0.5275] [F-score: 0.5297] [T: 0.32]
# [# features: 7708] [random attemps: 0] [prec: 0.4391] [rec: 0.4517] [F-score: 0.4453] [T: 0.30]
# [# features: 7708] [random attemps: 1] [prec: 0.4844] [rec: 0.4547] [F-score: 0.4691] [T: 0.24]
# [# features: 7708] [random attemps: 2] [prec: 0.5206] [rec: 0.5308] [F-score: 0.5257] [T: 0.27]
# [# features: 7708] [random attemps: 3] [prec: 0.5174] [rec: 0.5030] [F-score: 0.5101] [T: 0.25]
# [# features: 7708] [random attemps: 4] [prec: 0.5274] [rec: 0.5306] [F-score: 0.5290] [T: 0.27]
# [# features: 7708] [random attemps: 5] [prec: 0.5006] [rec: 0.5121] [F-score: 0.5063] [T: 0.27]
# [# features: 7708] [random attemps: 6] [prec: 0.5428] [rec: 0.5048] [F-score: 0.5231] [T: 0.24]
# [# features: 7708] [random attemps: 7] [prec: 0.4313] [rec: 0.4626] [F-score: 0.4464] [T: 0.25]
# [# features: 7708] [random attemps: 8] [prec: 0.5244] [rec: 0.5169] [F-score: 0.5206] [T: 0.26]
# [# features: 7708] [random attemps: 9] [prec: 0.5113] [rec: 0.5229] [F-score: 0.5171] [T: 0.24]
# [# features: 7708] [random attemps: 10] [prec: 0.5576] [rec: 0.5586] [F-score: 0.5581] [T: 0.24]
# [# features: 7708] [random attemps: 11] [prec: 0.4952] [rec: 0.5030] [F-score: 0.4991] [T: 0.27]
# [# features: 7708] [random attemps: 12] [prec: 0.4863] [rec: 0.4982] [F-score: 0.4922] [T: 0.35]
# [# features: 7708] [random attemps: 13] [prec: 0.5723] [rec: 0.5525] [F-score: 0.5622] [T: 0.28]
# [# features: 7708] [random attemps: 14] [prec: 0.5005] [rec: 0.5199] [F-score: 0.5100] [T: 0.30]
# [# features: 7708] [random attemps: 15] [prec: 0.5269] [rec: 0.5136] [F-score: 0.5202] [T: 0.31]
# [# features: 7708] [random attemps: 16] [prec: 0.5147] [rec: 0.5169] [F-score: 0.5158] [T: 0.31]
# [# features: 7708] [random attemps: 17] [prec: 0.5674] [rec: 0.5773] [F-score: 0.5723] [T: 0.26]
# [# features: 7708] [random attemps: 18] [prec: 0.5378] [rec: 0.4889] [F-score: 0.5122] [T: 0.25]
# [# features: 7708] [random attemps: 19] [prec: 0.4571] [rec: 0.4702] [F-score: 0.4635] [T: 0.28]
# [# features: 7708] [random attemps: 20] [prec: 0.5472] [rec: 0.5278] [F-score: 0.5373] [T: 0.29]
# [# features: 7708] [random attemps: 21] [prec: 0.5361] [rec: 0.5308] [F-score: 0.5335] [T: 0.27]
# [# features: 7708] [random attemps: 22] [prec: 0.5085] [rec: 0.4982] [F-score: 0.5033] [T: 0.32]
# [# features: 7708] [random attemps: 23] [prec: 0.4113] [rec: 0.3987] [F-score: 0.4049] [T: 0.27]
# [# features: 7708] [random attemps: 24] [prec: 0.5342] [rec: 0.5199] [F-score: 0.5270] [T: 0.27]
# [# features: 7708] [random attemps: 25] [prec: 0.5217] [rec: 0.5028] [F-score: 0.5121] [T: 0.27]
# [# features: 7708] [random attemps: 26] [prec: 0.4548] [rec: 0.4734] [F-score: 0.4639] [T: 0.29]
# [# features: 7708] [random attemps: 27] [prec: 0.4471] [rec: 0.4591] [F-score: 0.4530] [T: 0.26]
# [# features: 7708] [random attemps: 28] [prec: 0.4440] [rec: 0.4626] [F-score: 0.4531] [T: 0.29]
# [# features: 7708] [random attemps: 29] [prec: 0.4851] [rec: 0.4764] [F-score: 0.4807] [T: 0.28]
# [# features: 7708] [random attemps: 30] [prec: 0.4781] [rec: 0.4671] [F-score: 0.4725] [T: 0.32]
# [# features: 7708] [random attemps: 31] [prec: 0.4749] [rec: 0.4873] [F-score: 0.4810] [T: 0.30]
# [# features: 7708] [random attemps: 32] [prec: 0.5332] [rec: 0.5046] [F-score: 0.5185] [T: 0.37]
# [# features: 7708] [random attemps: 33] [prec: 0.5104] [rec: 0.5338] [F-score: 0.5218] [T: 0.34]
# [# features: 7708] [random attemps: 34] [prec: 0.4257] [rec: 0.4517] [F-score: 0.4383] [T: 0.25]
# [# features: 7708] [random attemps: 35] [prec: 0.4938] [rec: 0.4748] [F-score: 0.4841] [T: 0.27]
# [# features: 7708] [random attemps: 36] [prec: 0.5113] [rec: 0.5197] [F-score: 0.5154] [T: 0.26]
# [# features: 7708] [random attemps: 37] [prec: 0.5344] [rec: 0.5308] [F-score: 0.5326] [T: 0.25]
# [# features: 7708] [random attemps: 38] [prec: 0.4375] [rec: 0.4626] [F-score: 0.4497] [T: 0.26]
# [# features: 7708] [random attemps: 39] [prec: 0.4946] [rec: 0.4949] [F-score: 0.4948] [T: 0.25]
# [# features: 7708] [random attemps: 40] [prec: 0.3771] [rec: 0.3943] [F-score: 0.3855] [T: 0.25]
# [# features: 7708] [random attemps: 41] [prec: 0.4746] [rec: 0.4626] [F-score: 0.4685] [T: 0.25]
# [# features: 7708] [random attemps: 42] [prec: 0.5099] [rec: 0.4780] [F-score: 0.4935] [T: 0.28]
# [# features: 7708] [random attemps: 43] [prec: 0.6111] [rec: 0.5990] [F-score: 0.6050] [T: 0.26]
# [# features: 7708] [random attemps: 44] [prec: 0.4800] [rec: 0.4952] [F-score: 0.4875] [T: 0.27]
# [# features: 7708] [random attemps: 45] [prec: 0.4461] [rec: 0.4505] [F-score: 0.4483] [T: 0.27]
# [# features: 7708] [random attemps: 46] [prec: 0.5071] [rec: 0.4889] [F-score: 0.4979] [T: 0.27]
# [# features: 7708] [random attemps: 47] [prec: 0.5929] [rec: 0.5960] [F-score: 0.5944] [T: 0.33]
# [# features: 7708] [random attemps: 48] [prec: 0.5102] [rec: 0.5248] [F-score: 0.5174] [T: 0.29]
# [# features: 7708] [random attemps: 49] [prec: 0.5206] [rec: 0.5227] [F-score: 0.5216] [T: 0.29]
# [# features: 7709] [random attemps: 0] [prec: 0.6129] [rec: 0.5960] [F-score: 0.6044] [T: 0.31]
# [# features: 7709] [random attemps: 1] [prec: 0.5283] [rec: 0.5386] [F-score: 0.5334] [T: 0.30]
# [# features: 7709] [random attemps: 2] [prec: 0.5252] [rec: 0.5308] [F-score: 0.5280] [T: 0.29]
# [# features: 7709] [random attemps: 3] [prec: 0.4768] [rec: 0.4841] [F-score: 0.4804] [T: 0.26]
# [# features: 7709] [random attemps: 4] [prec: 0.5085] [rec: 0.5199] [F-score: 0.5141] [T: 0.29]
# [# features: 7709] [random attemps: 5] [prec: 0.4408] [rec: 0.4626] [F-score: 0.4514] [T: 0.25]
# [# features: 7709] [random attemps: 6] [prec: 0.5471] [rec: 0.5525] [F-score: 0.5498] [T: 0.24]
# [# features: 7709] [random attemps: 7] [prec: 0.4902] [rec: 0.4891] [F-score: 0.4897] [T: 0.27]
# [# features: 7709] [random attemps: 8] [prec: 0.4649] [rec: 0.4704] [F-score: 0.4677] [T: 0.26]
# [# features: 7709] [random attemps: 9] [prec: 0.4825] [rec: 0.4629] [F-score: 0.4725] [T: 0.24]
# [# features: 7709] [random attemps: 10] [prec: 0.5093] [rec: 0.5229] [F-score: 0.5160] [T: 0.25]
# [# features: 7709] [random attemps: 11] [prec: 0.4923] [rec: 0.5060] [F-score: 0.4991] [T: 0.26]
# [# features: 7709] [random attemps: 12] [prec: 0.5012] [rec: 0.4780] [F-score: 0.4894] [T: 0.25]
# [# features: 7709] [random attemps: 13] [prec: 0.5761] [rec: 0.5713] [F-score: 0.5737] [T: 0.25]
# [# features: 7709] [random attemps: 14] [prec: 0.5154] [rec: 0.5091] [F-score: 0.5122] [T: 0.27]
# [# features: 7709] [random attemps: 15] [prec: 0.5236] [rec: 0.5477] [F-score: 0.5354] [T: 0.30]
# [# features: 7709] [random attemps: 16] [prec: 0.5076] [rec: 0.5169] [F-score: 0.5122] [T: 0.31]
# [# features: 7709] [random attemps: 17] [prec: 0.5582] [rec: 0.5664] [F-score: 0.5623] [T: 0.29]
# [# features: 7709] [random attemps: 18] [prec: 0.5064] [rec: 0.5199] [F-score: 0.5131] [T: 0.32]
# [# features: 7709] [random attemps: 19] [prec: 0.4871] [rec: 0.4780] [F-score: 0.4825] [T: 0.32]
# [# features: 7709] [random attemps: 20] [prec: 0.5258] [rec: 0.5278] [F-score: 0.5268] [T: 0.25]
# [# features: 7709] [random attemps: 21] [prec: 0.5139] [rec: 0.5248] [F-score: 0.5193] [T: 0.27]
# [# features: 7709] [random attemps: 22] [prec: 0.5711] [rec: 0.5740] [F-score: 0.5725] [T: 0.25]
# [# features: 7709] [random attemps: 23] [prec: 0.4693] [rec: 0.4903] [F-score: 0.4796] [T: 0.25]
# [# features: 7709] [random attemps: 24] [prec: 0.5788] [rec: 0.5713] [F-score: 0.5750] [T: 0.25]
# [# features: 7709] [random attemps: 25] [prec: 0.4879] [rec: 0.5121] [F-score: 0.4997] [T: 0.27]
# [# features: 7709] [random attemps: 26] [prec: 0.5065] [rec: 0.4780] [F-score: 0.4918] [T: 0.24]
# [# features: 7709] [random attemps: 27] [prec: 0.5555] [rec: 0.5634] [F-score: 0.5594] [T: 0.26]
# [# features: 7709] [random attemps: 28] [prec: 0.4086] [rec: 0.4239] [F-score: 0.4161] [T: 0.24]
# [# features: 7709] [random attemps: 29] [prec: 0.4972] [rec: 0.4921] [F-score: 0.4947] [T: 0.25]
# [# features: 7709] [random attemps: 30] [prec: 0.4045] [rec: 0.4149] [F-score: 0.4096] [T: 0.24]
# [# features: 7709] [random attemps: 31] [prec: 0.4923] [rec: 0.5060] [F-score: 0.4991] [T: 0.27]
# [# features: 7709] [random attemps: 32] [prec: 0.5154] [rec: 0.5139] [F-score: 0.5147] [T: 0.30]
# [# features: 7709] [random attemps: 33] [prec: 0.5094] [rec: 0.5229] [F-score: 0.5161] [T: 0.30]
# [# features: 7709] [random attemps: 34] [prec: 0.4925] [rec: 0.4780] [F-score: 0.4852] [T: 0.31]
# [# features: 7709] [random attemps: 35] [prec: 0.5039] [rec: 0.4949] [F-score: 0.4994] [T: 0.33]
# [# features: 7709] [random attemps: 36] [prec: 0.5540] [rec: 0.5386] [F-score: 0.5462] [T: 0.32]
# [# features: 7709] [random attemps: 37] [prec: 0.4626] [rec: 0.4626] [F-score: 0.4626] [T: 0.25]
# [# features: 7709] [random attemps: 38] [prec: 0.4225] [rec: 0.4656] [F-score: 0.4430] [T: 0.28]
# [# features: 7709] [random attemps: 39] [prec: 0.5155] [rec: 0.5257] [F-score: 0.5206] [T: 0.25]
# [# features: 7709] [random attemps: 40] [prec: 0.5428] [rec: 0.5308] [F-score: 0.5368] [T: 0.25]
# [# features: 7709] [random attemps: 41] [prec: 0.5826] [rec: 0.5432] [F-score: 0.5622] [T: 0.27]
# [# features: 7709] [random attemps: 42] [prec: 0.5415] [rec: 0.5384] [F-score: 0.5399] [T: 0.25]
# [# features: 7709] [random attemps: 43] [prec: 0.5401] [rec: 0.5417] [F-score: 0.5409] [T: 0.26]
# [# features: 7709] [random attemps: 44] [prec: 0.4518] [rec: 0.4734] [F-score: 0.4624] [T: 0.27]
# [# features: 7709] [random attemps: 45] [prec: 0.5564] [rec: 0.5525] [F-score: 0.5545] [T: 0.23]
# [# features: 7709] [random attemps: 46] [prec: 0.5046] [rec: 0.5028] [F-score: 0.5037] [T: 0.29]
# [# features: 7709] [random attemps: 47] [prec: 0.5660] [rec: 0.5604] [F-score: 0.5632] [T: 0.25]
# [# features: 7709] [random attemps: 48] [prec: 0.5090] [rec: 0.4998] [F-score: 0.5044] [T: 0.25]
# [# features: 7709] [random attemps: 49] [prec: 0.4431] [rec: 0.4333] [F-score: 0.4382] [T: 0.31]
# [# features: 7710] [random attemps: 0] [prec: 0.5792] [rec: 0.5743] [F-score: 0.5767] [T: 0.30]
# [# features: 7710] [random attemps: 1] [prec: 0.4643] [rec: 0.4813] [F-score: 0.4726] [T: 0.30]
# [# features: 7710] [random attemps: 2] [prec: 0.4792] [rec: 0.4639] [F-score: 0.4714] [T: 0.48]
# [# features: 7710] [random attemps: 3] [prec: 0.5417] [rec: 0.5417] [F-score: 0.5417] [T: 0.34]
# [# features: 7710] [random attemps: 4] [prec: 0.4176] [rec: 0.4406] [F-score: 0.4288] [T: 0.30]
# [# features: 7710] [random attemps: 5] [prec: 0.4672] [rec: 0.4653] [F-score: 0.4663] [T: 0.30]
# [# features: 7710] [random attemps: 6] [prec: 0.5523] [rec: 0.5495] [F-score: 0.5509] [T: 0.28]
# [# features: 7710] [random attemps: 7] [prec: 0.4547] [rec: 0.4653] [F-score: 0.4599] [T: 0.23]
# [# features: 7710] [random attemps: 8] [prec: 0.4672] [rec: 0.4234] [F-score: 0.4442] [T: 0.26]
# [# features: 7710] [random attemps: 9] [prec: 0.4988] [rec: 0.4671] [F-score: 0.4825] [T: 0.27]
# [# features: 7710] [random attemps: 10] [prec: 0.5330] [rec: 0.5354] [F-score: 0.5342] [T: 0.26]
# [# features: 7710] [random attemps: 11] [prec: 0.5013] [rec: 0.4949] [F-score: 0.4981] [T: 0.27]
# [# features: 7710] [random attemps: 12] [prec: 0.5297] [rec: 0.4886] [F-score: 0.5083] [T: 0.25]
# [# features: 7710] [random attemps: 13] [prec: 0.5060] [rec: 0.4940] [F-score: 0.4999] [T: 0.28]
# [# features: 7710] [random attemps: 14] [prec: 0.4854] [rec: 0.4979] [F-score: 0.4916] [T: 0.27]
# [# features: 7710] [random attemps: 15] [prec: 0.4558] [rec: 0.4764] [F-score: 0.4659] [T: 0.25]
# [# features: 7710] [random attemps: 16] [prec: 0.4426] [rec: 0.4408] [F-score: 0.4417] [T: 0.27]
# [# features: 7710] [random attemps: 17] [prec: 0.5365] [rec: 0.5417] [F-score: 0.5390] [T: 0.32]
# [# features: 7710] [random attemps: 18] [prec: 0.4543] [rec: 0.4280] [F-score: 0.4408] [T: 0.30]
# [# features: 7710] [random attemps: 19] [prec: 0.4592] [rec: 0.5012] [F-score: 0.4793] [T: 0.30]
# [# features: 7710] [random attemps: 20] [prec: 0.4572] [rec: 0.4333] [F-score: 0.4449] [T: 0.31]
# [# features: 7710] [random attemps: 21] [prec: 0.4861] [rec: 0.4783] [F-score: 0.4821] [T: 0.28]
# [# features: 7710] [random attemps: 22] [prec: 0.5989] [rec: 0.5460] [F-score: 0.5712] [T: 0.23]
# [# features: 7710] [random attemps: 23] [prec: 0.4937] [rec: 0.4921] [F-score: 0.4929] [T: 0.25]
# [# features: 7710] [random attemps: 24] [prec: 0.4946] [rec: 0.5091] [F-score: 0.5017] [T: 0.26]
# [# features: 7710] [random attemps: 25] [prec: 0.5014] [rec: 0.5229] [F-score: 0.5119] [T: 0.28]
# [# features: 7710] [random attemps: 26] [prec: 0.4340] [rec: 0.4487] [F-score: 0.4412] [T: 0.26]
# [# features: 7710] [random attemps: 27] [prec: 0.5409] [rec: 0.5417] [F-score: 0.5413] [T: 0.25]
# [# features: 7710] [random attemps: 28] [prec: 0.4818] [rec: 0.4952] [F-score: 0.4884] [T: 0.24]
# [# features: 7710] [random attemps: 29] [prec: 0.5932] [rec: 0.5909] [F-score: 0.5921] [T: 0.23]
# [# features: 7710] [random attemps: 30] [prec: 0.4994] [rec: 0.4831] [F-score: 0.4911] [T: 0.24]
# [# features: 7710] [random attemps: 31] [prec: 0.5124] [rec: 0.5060] [F-score: 0.5092] [T: 0.25]
# [# features: 7710] [random attemps: 32] [prec: 0.5060] [rec: 0.5028] [F-score: 0.5044] [T: 0.27]
# [# features: 7710] [random attemps: 33] [prec: 0.5091] [rec: 0.4921] [F-score: 0.5005] [T: 0.27]
# [# features: 7710] [random attemps: 34] [prec: 0.5025] [rec: 0.4979] [F-score: 0.5002] [T: 0.34]
# [# features: 7710] [random attemps: 35] [prec: 0.5516] [rec: 0.5386] [F-score: 0.5450] [T: 0.30]
# [# features: 7710] [random attemps: 36] [prec: 0.4995] [rec: 0.5030] [F-score: 0.5012] [T: 0.30]
# [# features: 7710] [random attemps: 37] [prec: 0.5055] [rec: 0.5060] [F-score: 0.5058] [T: 0.34]
# [# features: 7710] [random attemps: 38] [prec: 0.5929] [rec: 0.5296] [F-score: 0.5595] [T: 0.30]
# [# features: 7710] [random attemps: 39] [prec: 0.5443] [rec: 0.5414] [F-score: 0.5429] [T: 0.28]
# [# features: 7710] [random attemps: 40] [prec: 0.4267] [rec: 0.4406] [F-score: 0.4335] [T: 0.24]
# [# features: 7710] [random attemps: 41] [prec: 0.4678] [rec: 0.4764] [F-score: 0.4721] [T: 0.27]
# [# features: 7710] [random attemps: 42] [prec: 0.5106] [rec: 0.4967] [F-score: 0.5036] [T: 0.25]
# [# features: 7710] [random attemps: 43] [prec: 0.4844] [rec: 0.4919] [F-score: 0.4881] [T: 0.25]
# [# features: 7710] [random attemps: 44] [prec: 0.5237] [rec: 0.5308] [F-score: 0.5272] [T: 0.25]
# ...
# [# features: 7786] [random attemps: 45] [prec: 0.5078] [rec: 0.4919] [F-score: 0.4997] [T: 0.18]
# [# features: 7786] [random attemps: 46] [prec: 0.4396] [rec: 0.4454] [F-score: 0.4425] [T: 0.21]
# [# features: 7786] [random attemps: 47] [prec: 0.5467] [rec: 0.5356] [F-score: 0.5411] [T: 0.20]
# [# features: 7786] [random attemps: 48] [prec: 0.4773] [rec: 0.4871] [F-score: 0.4821] [T: 0.20]
# [# features: 7786] [random attemps: 49] [prec: 0.4849] [rec: 0.4810] [F-score: 0.4830] [T: 0.21]
# [# features: 7787] [random attemps: 0] [prec: 0.5121] [rec: 0.5088] [F-score: 0.5104] [T: 0.24]
# [# features: 7787] [random attemps: 1] [prec: 0.5059] [rec: 0.4998] [F-score: 0.5028] [T: 0.22]
# [# features: 7787] [random attemps: 2] [prec: 0.4943] [rec: 0.4707] [F-score: 0.4822] [T: 0.23]
# [# features: 7787] [random attemps: 3] [prec: 0.4885] [rec: 0.5012] [F-score: 0.4948] [T: 0.24]
# [# features: 7787] [random attemps: 4] [prec: 0.4882] [rec: 0.4949] [F-score: 0.4915] [T: 0.24]
# [# features: 7787] [random attemps: 5] [prec: 0.4936] [rec: 0.5139] [F-score: 0.5035] [T: 0.24]
# [# features: 7787] [random attemps: 6] [prec: 0.5268] [rec: 0.5368] [F-score: 0.5318] [T: 0.22]
# [# features: 7787] [random attemps: 7] [prec: 0.5194] [rec: 0.5308] [F-score: 0.5250] [T: 0.20]
# [# features: 7787] [random attemps: 8] [prec: 0.6012] [rec: 0.5821] [F-score: 0.5915] [T: 0.20]
# [# features: 7787] [random attemps: 9] [prec: 0.5443] [rec: 0.5525] [F-score: 0.5484] [T: 0.22]
# [# features: 7787] [random attemps: 10] [prec: 0.4535] [rec: 0.4764] [F-score: 0.4647] [T: 0.21]
# [# features: 7787] [random attemps: 11] [prec: 0.4750] [rec: 0.4873] [F-score: 0.4811] [T: 0.19]
# [# features: 7787] [random attemps: 12] [prec: 0.5708] [rec: 0.5463] [F-score: 0.5582] [T: 0.19]
# [# features: 7787] [random attemps: 13] [prec: 0.6503] [rec: 0.6069] [F-score: 0.6278] [T: 0.23]
# [# features: 7787] [random attemps: 14] [prec: 0.5342] [rec: 0.5417] [F-score: 0.5379] [T: 0.27]
# [# features: 7787] [random attemps: 15] [prec: 0.4646] [rec: 0.4843] [F-score: 0.4742] [T: 0.29]
# [# features: 7787] [random attemps: 16] [prec: 0.4725] [rec: 0.4873] [F-score: 0.4798] [T: 0.24]
# [# features: 7787] [random attemps: 17] [prec: 0.4592] [rec: 0.4704] [F-score: 0.4647] [T: 0.22]
# [# features: 7787] [random attemps: 18] [prec: 0.5022] [rec: 0.4778] [F-score: 0.4897] [T: 0.33]
# [# features: 7787] [random attemps: 19] [prec: 0.5167] [rec: 0.5199] [F-score: 0.5183] [T: 0.32]
# [# features: 7787] [random attemps: 20] [prec: 0.5063] [rec: 0.5058] [F-score: 0.5060] [T: 0.28]
# [# features: 7787] [random attemps: 21] [prec: 0.5553] [rec: 0.5525] [F-score: 0.5539] [T: 0.20]
# [# features: 7787] [random attemps: 22] [prec: 0.4963] [rec: 0.5030] [F-score: 0.4996] [T: 0.22]
# [# features: 7787] [random attemps: 23] [prec: 0.5714] [rec: 0.5495] [F-score: 0.5603] [T: 0.23]
# [# features: 7787] [random attemps: 24] [prec: 0.4625] [rec: 0.4287] [F-score: 0.4450] [T: 0.23]
# [# features: 7787] [random attemps: 25] [prec: 0.5267] [rec: 0.5278] [F-score: 0.5272] [T: 0.23]
# [# features: 7787] [random attemps: 26] [prec: 0.5127] [rec: 0.5058] [F-score: 0.5092] [T: 0.22]
# [# features: 7787] [random attemps: 27] [prec: 0.4666] [rec: 0.4618] [F-score: 0.4642] [T: 0.23]
# [# features: 7787] [random attemps: 28] [prec: 0.4771] [rec: 0.5030] [F-score: 0.4897] [T: 0.22]
# [# features: 7787] [random attemps: 29] [prec: 0.5651] [rec: 0.5833] [F-score: 0.5741] [T: 0.24]
# [# features: 7787] [random attemps: 30] [prec: 0.5110] [rec: 0.5229] [F-score: 0.5169] [T: 0.24]
# [# features: 7787] [random attemps: 31] [prec: 0.4036] [rec: 0.4128] [F-score: 0.4081] [T: 0.25]
# [# features: 7787] [random attemps: 32] [prec: 0.4048] [rec: 0.3977] [F-score: 0.4012] [T: 0.21]
# [# features: 7787] [random attemps: 33] [prec: 0.5668] [rec: 0.5134] [F-score: 0.5388] [T: 0.24]
# [# features: 7787] [random attemps: 34] [prec: 0.4571] [rec: 0.4764] [F-score: 0.4666] [T: 0.29]
# [# features: 7787] [random attemps: 35] [prec: 0.4806] [rec: 0.4563] [F-score: 0.4681] [T: 0.41]
# [# features: 7787] [random attemps: 36] [prec: 0.5511] [rec: 0.5447] [F-score: 0.5479] [T: 0.41]
# [# features: 7787] [random attemps: 37] [prec: 0.5550] [rec: 0.5495] [F-score: 0.5522] [T: 0.47]
# [# features: 7787] [random attemps: 38] [prec: 0.5067] [rec: 0.5136] [F-score: 0.5102] [T: 0.48]
# [# features: 7787] [random attemps: 39] [prec: 0.4394] [rec: 0.4454] [F-score: 0.4424] [T: 0.28]
# [# features: 7787] [random attemps: 40] [prec: 0.4616] [rec: 0.4502] [F-score: 0.4559] [T: 0.25]
# [# features: 7787] [random attemps: 41] [prec: 0.5525] [rec: 0.5306] [F-score: 0.5413] [T: 0.26]
# [# features: 7787] [random attemps: 42] [prec: 0.5835] [rec: 0.5604] [F-score: 0.5717] [T: 0.22]
# [# features: 7787] [random attemps: 43] [prec: 0.5290] [rec: 0.5354] [F-score: 0.5322] [T: 0.24]
# [# features: 7787] [random attemps: 44] [prec: 0.5337] [rec: 0.5275] [F-score: 0.5306] [T: 0.31]
# [# features: 7787] [random attemps: 45] [prec: 0.5200] [rec: 0.5338] [F-score: 0.5268] [T: 0.33]
# [# features: 7787] [random attemps: 46] [prec: 0.6310] [rec: 0.6208] [F-score: 0.6259] [T: 0.36]
# [# features: 7787] [random attemps: 47] [prec: 0.3724] [rec: 0.3850] [F-score: 0.3786] [T: 0.32]
# [# features: 7787] [random attemps: 48] [prec: 0.4378] [rec: 0.4269] [F-score: 0.4323] [T: 0.31]
# [# features: 7787] [random attemps: 49] [prec: 0.4122] [rec: 0.4260] [F-score: 0.4190] [T: 0.32]
# [# features: 7788] [random attemps: 0] [prec: 0.6166] [rec: 0.5652] [F-score: 0.5898] [T: 0.26]
# [# features: 7788] [random attemps: 1] [prec: 0.4235] [rec: 0.3729] [F-score: 0.3966] [T: 0.23]
# [# features: 7788] [random attemps: 2] [prec: 0.3822] [rec: 0.4052] [F-score: 0.3934] [T: 0.22]
# [# features: 7788] [random attemps: 3] [prec: 0.5468] [rec: 0.4636] [F-score: 0.5018] [T: 0.26]
# [# features: 7788] [random attemps: 4] [prec: 0.5055] [rec: 0.5197] [F-score: 0.5125] [T: 0.25]
# [# features: 7788] [random attemps: 5] [prec: 0.4643] [rec: 0.4843] [F-score: 0.4741] [T: 0.38]
# [# features: 7788] [random attemps: 6] [prec: 0.5529] [rec: 0.5634] [F-score: 0.5581] [T: 0.38]
# [# features: 7788] [random attemps: 7] [prec: 0.5531] [rec: 0.5417] [F-score: 0.5473] [T: 0.33]
# [# features: 7788] [random attemps: 8] [prec: 0.5604] [rec: 0.5435] [F-score: 0.5518] [T: 0.36]
# [# features: 7788] [random attemps: 9] [prec: 0.4803] [rec: 0.4593] [F-score: 0.4695] [T: 0.33]
# [# features: 7788] [random attemps: 10] [prec: 0.5119] [rec: 0.5030] [F-score: 0.5074] [T: 0.30]
# [# features: 7788] [random attemps: 11] [prec: 0.5612] [rec: 0.5634] [F-score: 0.5623] [T: 0.24]
# [# features: 7788] [random attemps: 12] [prec: 0.5148] [rec: 0.5199] [F-score: 0.5174] [T: 0.25]
# [# features: 7788] [random attemps: 13] [prec: 0.5910] [rec: 0.6021] [F-score: 0.5965] [T: 0.30]
# [# features: 7788] [random attemps: 14] [prec: 0.4542] [rec: 0.4484] [F-score: 0.4513] [T: 0.37]
# [# features: 7788] [random attemps: 15] [prec: 0.5340] [rec: 0.5136] [F-score: 0.5236] [T: 0.29]
# [# features: 7788] [random attemps: 16] [prec: 0.4768] [rec: 0.4952] [F-score: 0.4858] [T: 0.25]
# [# features: 7788] [random attemps: 17] [prec: 0.4900] [rec: 0.4611] [F-score: 0.4751] [T: 0.27]
# [# features: 7788] [random attemps: 18] [prec: 0.4012] [rec: 0.4149] [F-score: 0.4079] [T: 0.26]
# [# features: 7788] [random attemps: 19] [prec: 0.5291] [rec: 0.5042] [F-score: 0.5163] [T: 0.27]
# [# features: 7788] [random attemps: 20] [prec: 0.5287] [rec: 0.5417] [F-score: 0.5351] [T: 0.33]
# [# features: 7788] [random attemps: 21] [prec: 0.4801] [rec: 0.4780] [F-score: 0.4791] [T: 0.24]
# [# features: 7788] [random attemps: 22] [prec: 0.4640] [rec: 0.4563] [F-score: 0.4601] [T: 0.40]
# [# features: 7788] [random attemps: 23] [prec: 0.5403] [rec: 0.5248] [F-score: 0.5324] [T: 0.47]
# [# features: 7788] [random attemps: 24] [prec: 0.4535] [rec: 0.4535] [F-score: 0.4535] [T: 0.34]
# [# features: 7788] [random attemps: 25] [prec: 0.4848] [rec: 0.4952] [F-score: 0.4899] [T: 0.26]
# [# features: 7788] [random attemps: 26] [prec: 0.4620] [rec: 0.4762] [F-score: 0.4690] [T: 0.24]
# [# features: 7788] [random attemps: 27] [prec: 0.4589] [rec: 0.4669] [F-score: 0.4629] [T: 0.24]
# [# features: 7788] [random attemps: 28] [prec: 0.5019] [rec: 0.4949] [F-score: 0.4984] [T: 0.24]
# [# features: 7788] [random attemps: 29] [prec: 0.4437] [rec: 0.4517] [F-score: 0.4476] [T: 0.25]
# [# features: 7788] [random attemps: 30] [prec: 0.4532] [rec: 0.4454] [F-score: 0.4493] [T: 0.22]
# [# features: 7788] [random attemps: 31] [prec: 0.4412] [rec: 0.4412] [F-score: 0.4412] [T: 0.27]
# [# features: 7788] [random attemps: 32] [prec: 0.4874] [rec: 0.4982] [F-score: 0.4927] [T: 0.25]
# [# features: 7788] [random attemps: 33] [prec: 0.4972] [rec: 0.4952] [F-score: 0.4962] [T: 0.23]
# [# features: 7788] [random attemps: 34] [prec: 0.5213] [rec: 0.5139] [F-score: 0.5176] [T: 0.23]
# [# features: 7788] [random attemps: 35] [prec: 0.4965] [rec: 0.5060] [F-score: 0.5012] [T: 0.27]
# [# features: 7788] [random attemps: 36] [prec: 0.5115] [rec: 0.5167] [F-score: 0.5141] [T: 0.28]
# [# features: 7788] [random attemps: 37] [prec: 0.4774] [rec: 0.4750] [F-score: 0.4762] [T: 0.26]
# [# features: 7788] [random attemps: 38] [prec: 0.5213] [rec: 0.5336] [F-score: 0.5274] [T: 0.28]
# [# features: 7788] [random attemps: 39] [prec: 0.4224] [rec: 0.4406] [F-score: 0.4313] [T: 0.33]
# [# features: 7788] [random attemps: 40] [prec: 0.4773] [rec: 0.4813] [F-score: 0.4793] [T: 0.30]
# [# features: 7788] [random attemps: 41] [prec: 0.5071] [rec: 0.5058] [F-score: 0.5065] [T: 0.37]
# [# features: 7788] [random attemps: 42] [prec: 0.5678] [rec: 0.5632] [F-score: 0.5655] [T: 0.84]
# [# features: 7788] [random attemps: 43] [prec: 0.5147] [rec: 0.5169] [F-score: 0.5158] [T: 1.56]
# [# features: 7788] [random attemps: 44] [prec: 0.4914] [rec: 0.4623] [F-score: 0.4764] [T: 0.67]
# [# features: 7788] [random attemps: 45] [prec: 0.4484] [rec: 0.4484] [F-score: 0.4484] [T: 0.32]
# [# features: 7788] [random attemps: 46] [prec: 0.5361] [rec: 0.5384] [F-score: 0.5372] [T: 0.50]
# [# features: 7788] [random attemps: 47] [prec: 0.5386] [rec: 0.5356] [F-score: 0.5371] [T: 0.31]
# [# features: 7788] [random attemps: 48] [prec: 0.6022] [rec: 0.5574] [F-score: 0.5789] [T: 0.27]
# [# features: 7788] [random attemps: 49] [prec: 0.5325] [rec: 0.5528] [F-score: 0.5424] [T: 0.34]
# [# features: 7789] [random attemps: 0] [prec: 0.5451] [rec: 0.5306] [F-score: 0.5377] [T: 0.28]
# [# features: 7789] [random attemps: 1] [prec: 0.4481] [rec: 0.4444] [F-score: 0.4462] [T: 0.21]
# [# features: 7789] [random attemps: 2] [prec: 0.4270] [rec: 0.4345] [F-score: 0.4307] [T: 0.21]
# [# features: 7789] [random attemps: 3] [prec: 0.5256] [rec: 0.5275] [F-score: 0.5266] [T: 0.23]
# [# features: 7789] [random attemps: 4] [prec: 0.4180] [rec: 0.4158] [F-score: 0.4169] [T: 0.24]
# [# features: 7789] [random attemps: 5] [prec: 0.4623] [rec: 0.4440] [F-score: 0.4529] [T: 0.21]
# [# features: 7789] [random attemps: 6] [prec: 0.5076] [rec: 0.5169] [F-score: 0.5122] [T: 0.22]
# [# features: 7789] [random attemps: 7] [prec: 0.4742] [rec: 0.4704] [F-score: 0.4723] [T: 0.23]
# [# features: 7789] [random attemps: 8] [prec: 0.5104] [rec: 0.5139] [F-score: 0.5121] [T: 0.29]
# [# features: 7789] [random attemps: 9] [prec: 0.4600] [rec: 0.4626] [F-score: 0.4613] [T: 0.23]
# [# features: 7789] [random attemps: 10] [prec: 0.5233] [rec: 0.5275] [F-score: 0.5254] [T: 0.26]
# [# features: 7789] [random attemps: 11] [prec: 0.4540] [rec: 0.4563] [F-score: 0.4551] [T: 0.26]
# [# features: 7789] [random attemps: 12] [prec: 0.4520] [rec: 0.4734] [F-score: 0.4625] [T: 0.30]
# [# features: 7789] [random attemps: 13] [prec: 0.4093] [rec: 0.4116] [F-score: 0.4104] [T: 0.29]
# [# features: 7789] [random attemps: 14] [prec: 0.4591] [rec: 0.4704] [F-score: 0.4647] [T: 0.28]
# [# features: 7789] [random attemps: 15] [prec: 0.4850] [rec: 0.5012] [F-score: 0.4929] [T: 0.23]
# [# features: 7789] [random attemps: 16] [prec: 0.3887] [rec: 0.4082] [F-score: 0.3982] [T: 0.21]
# [# features: 7789] [random attemps: 17] [prec: 0.5082] [rec: 0.4949] [F-score: 0.5015] [T: 0.24]
# [# features: 7789] [random attemps: 18] [prec: 0.5001] [rec: 0.4861] [F-score: 0.4930] [T: 0.25]
# [# features: 7789] [random attemps: 19] [prec: 0.4249] [rec: 0.4626] [F-score: 0.4429] [T: 0.25]
# [# features: 7789] [random attemps: 20] [prec: 0.4600] [rec: 0.4702] [F-score: 0.4650] [T: 0.25]
# [# features: 7789] [random attemps: 21] [prec: 0.5346] [rec: 0.5447] [F-score: 0.5396] [T: 0.27]
# [# features: 7789] [random attemps: 22] [prec: 0.5252] [rec: 0.5338] [F-score: 0.5295] [T: 0.36]
# [# features: 7789] [random attemps: 23] [prec: 0.4602] [rec: 0.4533] [F-score: 0.4567] [T: 0.22]
# [# features: 7789] [random attemps: 24] [prec: 0.5028] [rec: 0.4982] [F-score: 0.5005] [T: 0.26]
# [# features: 7789] [random attemps: 25] [prec: 0.4184] [rec: 0.4257] [F-score: 0.4220] [T: 0.29]
# [# features: 7789] [random attemps: 26] [prec: 0.5329] [rec: 0.5308] [F-score: 0.5318] [T: 0.26]
# [# features: 7789] [random attemps: 27] [prec: 0.4155] [rec: 0.4227] [F-score: 0.4191] [T: 0.26]
# [# features: 7789] [random attemps: 28] [prec: 0.4333] [rec: 0.4315] [F-score: 0.4324] [T: 0.24]
# [# features: 7789] [random attemps: 29] [prec: 0.4856] [rec: 0.4952] [F-score: 0.4903] [T: 0.24]
# [# features: 7789] [random attemps: 30] [prec: 0.4779] [rec: 0.4841] [F-score: 0.4809] [T: 0.24]
# [# features: 7789] [random attemps: 31] [prec: 0.5362] [rec: 0.5278] [F-score: 0.5320] [T: 0.25]
# [# features: 7789] [random attemps: 32] [prec: 0.5241] [rec: 0.4547] [F-score: 0.4869] [T: 0.23]
# [# features: 7789] [random attemps: 33] [prec: 0.4987] [rec: 0.5121] [F-score: 0.5053] [T: 0.25]
# [# features: 7789] [random attemps: 34] [prec: 0.5514] [rec: 0.5664] [F-score: 0.5588] [T: 0.40]
# [# features: 7789] [random attemps: 35] [prec: 0.4558] [rec: 0.4623] [F-score: 0.4591] [T: 0.44]
# [# features: 7789] [random attemps: 36] [prec: 0.4712] [rec: 0.4764] [F-score: 0.4738] [T: 0.34]
# [# features: 7789] [random attemps: 37] [prec: 0.5357] [rec: 0.5060] [F-score: 0.5204] [T: 0.34]
# [# features: 7789] [random attemps: 38] [prec: 0.5021] [rec: 0.5088] [F-score: 0.5054] [T: 0.29]
# [# features: 7789] [random attemps: 39] [prec: 0.4645] [rec: 0.4764] [F-score: 0.4704] [T: 0.97]
# [# features: 7789] [random attemps: 40] [prec: 0.5004] [rec: 0.4593] [F-score: 0.4790] [T: 0.53]
# [# features: 7789] [random attemps: 41] [prec: 0.4720] [rec: 0.4841] [F-score: 0.4779] [T: 0.36]
# [# features: 7789] [random attemps: 42] [prec: 0.4827] [rec: 0.4949] [F-score: 0.4887] [T: 0.33]
# [# features: 7789] [random attemps: 43] [prec: 0.5049] [rec: 0.5197] [F-score: 0.5122] [T: 0.40]
# [# features: 7789] [random attemps: 44] [prec: 0.4165] [rec: 0.4257] [F-score: 0.4211] [T: 0.35]
# [# features: 7789] [random attemps: 45] [prec: 0.5268] [rec: 0.5278] [F-score: 0.5273] [T: 0.30]
# [# features: 7789] [random attemps: 46] [prec: 0.4439] [rec: 0.4565] [F-score: 0.4501] [T: 0.36]
# [# features: 7789] [random attemps: 47] [prec: 0.4796] [rec: 0.4767] [F-score: 0.4781] [T: 0.39]
# [# features: 7789] [random attemps: 48] [prec: 0.4481] [rec: 0.4656] [F-score: 0.4567] [T: 0.35]
# [# features: 7789] [random attemps: 49] [prec: 0.5312] [rec: 0.5479] [F-score: 0.5395] [T: 0.45]
# [# features: 7790] [random attemps: 0] [prec: 0.6268] [rec: 0.6205] [F-score: 0.6237] [T: 0.31]
# [# features: 7790] [random attemps: 1] [prec: 0.4469] [rec: 0.4621] [F-score: 0.4544] [T: 0.36]
# [# features: 7790] [random attemps: 2] [prec: 0.4565] [rec: 0.4704] [F-score: 0.4634] [T: 0.29]
# [# features: 7790] [random attemps: 3] [prec: 0.5339] [rec: 0.5417] [F-score: 0.5378] [T: 0.26]
# [# features: 7790] [random attemps: 4] [prec: 0.5362] [rec: 0.5338] [F-score: 0.5350] [T: 0.25]
# [# features: 7790] [random attemps: 5] [prec: 0.4652] [rec: 0.4671] [F-score: 0.4661] [T: 0.28]
# [# features: 7790] [random attemps: 6] [prec: 0.4140] [rec: 0.4209] [F-score: 0.4174] [T: 0.30]
# [# features: 7790] [random attemps: 7] [prec: 0.5133] [rec: 0.5308] [F-score: 0.5219] [T: 0.30]
# [# features: 7790] [random attemps: 8] [prec: 0.4012] [rec: 0.4037] [F-score: 0.4025] [T: 0.33]
# [# features: 7790] [random attemps: 9] [prec: 0.5451] [rec: 0.5419] [F-score: 0.5435] [T: 0.30]
