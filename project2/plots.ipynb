# %%
# training : 0.395 seconds
# testing : 30.366 seconds
# D= 10  et C = 1 result: 0.44795
# testing : 28.645 seconds
# D= 10  et C = 10 result: 0.44825
# testing : 40.285 seconds
# D= 10  et C = 100 result: 0.44831666666666664


# training : 0.576 seconds
# testing : 30.228 seconds
# D= 20  et C = 1 result: 0.5276666666666666
# testing : 31.293 seconds
# D= 20  et C = 10 result: 0.5277666666666667
# testing : 42.842 seconds
# D= 20  et C = 100 result: 0.5271



# training : 1.448 seconds
# testing : 25.176 seconds
# D= 50  et C = 1 result: 0.7512166666666666
# testing : 22.050 seconds
# D= 50  et C = 10 result: 0.74865
# testing : 27.994 seconds
# D= 50  et C = 100 result: 0.7462833333333333


# training : 2.921 seconds
# testing : 26.495 seconds
# D= 100  et C = 1 result: 0.8478
# testing : 19.157 seconds
# D= 100  et C = 10 result: 0.8369166666666666
# testing : 23.049 seconds
# D= 100  et C = 100 result: 0.8227833333333333


# training : 5.789 seconds
# testing : 47.431 seconds
# D= 200  et C = 1 result: 0.9022333333333333
# testing : 33.552 seconds
# D= 200  et C = 10 result: 0.8905
# testing : 29.034 seconds
# D= 200  et C = 100 result: 0.8705


# training : 14.549 seconds
# testing : 89.564 seconds
# D= 500  et C = 1 result: 0.9318833333333333
# testing : 91.813 seconds
# D= 500  et C = 10 result: 0.9252333333333334
# testing : 91.358 seconds
# D= 500  et C = 100 result: 0.92145


# training : 31.431 seconds
# testing : 200.515 seconds
# D= 1000  et C = 1 result: 0.9422333333333334
# testing : 175.413 seconds
# D= 1000  et C = 10 result: 0.9422833333333334
